# %% [markdown]
# ## Синтаксический анализатор SpaCy
#
# Одним из синтаксических анализаторов является Spacy. Библиотеки можно поставить при помощи pip, а как добавить **языковые модели** можно посмотреть [здесь](https://spacy.io/usage/models).

# %%
# Импортируемм нужные библиотеки.
import spacy
from spacy import displacy
from pprint import pprint
from collections import defaultdict
from tqdm import tqdm

# %%
# Загружаем языковую модель.
nlp = spacy.load("ru_core_news_sm")

# %% [markdown]
# Для анализа используем тексты новостей с сайта Лента.ру.

# %%
with open("data/lenta2018.txt", encoding="utf-8") as news_file: # Файл с новостями.
    text_news = [n.split("-----\n")[1] for n in news_file.read().split("=====\n")[1:]]

# %%
text_news[11]
# Out:
# 'Ракета-носитель «Союз-2.1а» с 11 спутниками стартовала с космодрома Восточный. Об этом сообщает Космический центр «Южный», который ведет прямую трансляцию запуска.Корабль должен доставить на орбиты 11 спутников, два из которых — российские спутники дистанционного зондирования Земли «Канопус-В» №3 и №4.Это уже третий пуск с Восточного. Предыдущий состоялся 28 ноября 2017 года и завершился неудачей — из-за неполадок с разгонным блоком была утеряна головная часть ракеты «Союз-2.1б» (с 19 спутниками на борту). В госкорпорации «Роскосмос» объяснили инцидент ошибкой в программном обеспечении разгонного блока и ракеты-носителя, заложенной еще 20 лет назад. Позже вице-премьер России Дмитрий Рогозин заявил, что при подготовке запуска сотрудники перепутали космодромы: «Союз-2.1б» запускали с Восточного, при этом параметры траектории рассчитали с учетом старта с Байконура.В ближайшие годы «Роскосмос» ставит задачу повысить долю успешных запусков ракет-носителей до 99 процентов.\n'

# %% [markdown]
# Дерево в Spacy представляется в виде дерева зависимостей: как совокупность вершин и связей между ними. Каждая вершина соответствует слову из предложения, у слова есть лемма (поле `lemma_`) и токен (поле `text`).

# %%
# Передаем текст новости в Spacy для разбора, получаем объект документа с результатами разбора.
doc = nlp(text_news[11])
# Перебираем предложения в тексте. 
# Но так как мне нужны первые два предложения, я превращаю итерируемый объект sents в список.
for s in list(doc.sents)[:2]:
    pprint(list([f'{t.lemma_} ({t.text})' for t in s]))
# Out:
# ['ракета (Ракета)',
#  '- (-)',
#  'носитель (носитель)',
#  '" («)',
#  'союз-2.1а (Союз-2.1а)',
#  '" (»)',
#  'с (с)',
#  '11 (11)',
#  'спутник (спутниками)',
#  'стартовать (стартовала)',
#  'с (с)',
#  'космодром (космодрома)',
#  'восточный (Восточный)',
#  '. (.)']
# ['Об (Об)',
#  'это (этом)',
#  'сообщать (сообщает)',
#  'космический (Космический)',
#  'центр (центр)',
#  '" («)',
#  'южный (Южный)',
#  '" (»)',
#  ', (,)',
#  'который (который)',
#  'вести (ведет)',
#  'прямой (прямую)',
#  'трансляция (трансляцию)',
#  'запуск (запуска)',
#  '. (.)']

# %% [markdown]
# Вместе со Spacy ставится библиотека dasplaycy, которая умеет отображать текст в виде деревьев зависимости. Посмотрим на первые два предложения.

# %%
for s in list(doc.sents)[:2]:
    displacy.render(s, style="dep", minify=True, jupyter=True, options={"distance":90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="946520469ccd4db7bd6d6b380b9a8507-0" class="displacy" width="950" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="50">Ракета-</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="140">носитель «</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="230">Союз-2.1а»</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="320">с</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="410">11</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NUM</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="500">спутниками</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="590">стартовала</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="680">с</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="770">космодрома</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0"><tspan class="displacy-word" fill="currentColor" x="860">Восточный.</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">PROPN</tspan></text><g class="displacy-arrow"><path class="displacy-arc" id="arrow-946520469ccd4db7bd6d6b380b9a8507-0-0" stroke-width="2px" d="M70,182.0 C70,2.0 590.0,2.0 590.0,182.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-946520469ccd4db7bd6d6b380b9a8507-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath></text><path class="displacy-arrowhead" d="M70,184.0 L62,172.0 78,172.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-946520469ccd4db7bd6d6b380b9a8507-0-1" stroke-width="2px" d="M160,182.0 C160,47.0 585.0,47.0 585.0,182.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-946520469ccd4db7bd6d6b380b9a8507-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath></text><path class="displacy-arrowhead" d="M160,184.0 L152,172.0 168,172.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-946520469ccd4db7bd6d6b380b9a8507-0-2" stroke-width="2px" d="M160,182.0 C160,137.0 215.0,137.0 215.0,182.0" fill="none" stroke="currentColor"/><text dy="1.25 ...
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="5b6e7d5f756a4b1f9f77066d16bd08f0-0" class="displacy" width="1040" height="227.0" direction="ltr" style="max-width: none; height: 227.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr"><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="50">Об</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADP</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="140">этом</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PRON</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="230">сообщает</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="320">Космический</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADJ</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="410">центр «</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="500">Южный»,</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="590">который</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">PRON</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="680">ведет</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">VERB</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="770">прямую</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADJ</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="860">трансляцию</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan></text><text class="displacy-token" fill="currentColor" text-anchor="middle" y="137.0"><tspan class="displacy-word" fill="currentColor" x="950">запуска.</tspan><tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan></text><g class="displacy-arrow"><path class="displacy-arc" id="arrow-5b6e7d5f756a4b1f9f77066d16bd08f0-0-0" stroke-width="2px" d="M70,92.0 C70,47.0 135.0,47.0 135.0,92.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-5b6e7d5f756a4b1f9f77066d16bd08f0-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath></text><path class="displacy-arrowhead" d="M70,94.0 L62,82.0 78,82.0" fill="currentColor"/></g><g class="displacy-arrow"><path class="displacy-arc" id="arrow-5b6e7d5f756a4b1f9f77066d16bd08f0-0-1" stroke-width="2px" d="M160,92.0 C160,47.0 225.0,47.0 225.0,92.0" fill="none" stroke="currentColor"/><text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px"><textPath xlink:href="#arrow-5b6e7d5f756a4b1f9f77066d16bd08f0-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath></text><path class="displacy-arrowhead" d="M160,94.0 L152,82.0 168,82.0" fill="currentColor"/></g ...

# %% [markdown]
# Для предложения определено свойство `root`, которое является корневой вершиной предложения.
# Помимо леммы и токена, каждая вершина хранит список потомков `children`, список родителей `ancestors`, вид зависимости (роль слова при родителе) `dep_`, часть речи `tag_`.

# %%
sent0 = list(doc.sents)[0]
childs0 = list(sent0.root.children)
print(sent0.root, childs0)
print(childs0[0].lemma_, childs0[0].text, childs0[0].dep_, childs0[0].tag_, '->', list(childs0[0].ancestors)[0])
# Out:
# стартовала [Ракета, -, носитель, спутниками, космодрома, .]
# ракета Ракета nsubj NOUN -> стартовала

# %% [markdown]
# При анализе текстов существует задача оценки тональности текста. Тональность текста определяет какого роде слова содержатся в тексте - негативные или позитивные. Например, если у нас имеется отзыв на какой-то товар, услугу или организацию, мы можем определить, положительный это отзыв или отрицательный. Для оценки тональности отзыва используют, среди прочего, словари оценочной лексики.
#
# Один отзыв может содержать как критику, так и похвалу, в зависимости от того, что в нем рассматривается (Прекрасное обслуживание, но пироженые были несвежими). Код ниже использует словарь оценочной лексики для того, чтобы понять, какие глаголы сочетаются чаще с отрицательно окрашенными словами, а какие - с положительными.

# %%
# Загружаем словарь оценочной лексики.
with open("data/rusentilex_2017.txt", encoding="utf-8") as senti_file: 
    for i in range(18): # Пропускаем заголовок файла.
        _ = senti_file.readline()
        
    senti_words = {line.split(", ")[0]: line.split(", ")[3] for line in senti_file.readlines()}

# %%
# Посмотрим на первые 10 слов словаря.
list(senti_words.items())[:10]
# Out:
# [('аборт', 'negative'),
#  ('абортивный', 'negative'),
#  ('абракадабра', 'negative'),
#  ('абсурд', 'negative'),
#  ('абсурдность', 'negative'),
#  ('абсурдный', 'negative'),
#  ('авантюра', 'negative'),
#  ('авантюризм', 'negative'),
#  ('авантюрист', 'negative'),
#  ('авантюристический', 'negative')]

# %%
# Поиск эмоционально окрашенных потомков для SpaCy.
def find_sentiments_spacy(node, senti_words, sentiments):
    for child in node.children:
        if child.lemma_ in senti_words.keys():
            if node.lemma_ not in sentiments.keys():
                sentiments[node.lemma_] = defaultdict(int)
            sentiments[node.lemma_][senti_words[child.lemma_]] += 1

# %%
# Перебираем все прдложения первой новости и ищем эмоционально окрашенные слова.
sentiments = {}
for sent in doc.sents:
    find_sentiments_spacy(sent.root, senti_words, sentiments)
sentiments
# Out:
# {'объяснить': defaultdict(int, {'negative': 2}),
#  'заявить': defaultdict(int, {'negative': 1})}

# %%
# Найдем все эмоционально окрашенные фразы во всех новостях.
sentiments = {}
for sent_text in tqdm(text_news):
    doc = nlp(sent_text)
    for sentence in doc.sents:
        find_sentiments_spacy(sentence.root, senti_words, sentiments)
# Out:
# 100%|███████████████████████████████████████| 1708/1708 [01:38<00:00, 17.26it/s]

# %%
[(senti, vals) for senti,vals in sentiments.items() if vals['negative']>30], '\n----\n',\
[(senti, vals) for senti,vals in sentiments.items() if vals['positive']>30]
# Out:
# ([('признать',
#    defaultdict(int, {'negative': 44, 'positive': 7, 'neutral': 2})),
#   ('стать',
#    defaultdict(int,
#                {'negative': 42,
#                 'positive': 35,
#                 'neutral': 18,
#                 'positive/negative': 3})),
#   ('мочь',
#    defaultdict(int,
#                {'negative': 34,
#                 'positive': 18,
#                 'neutral': 11,
#                 'positive/negative': 3,
#                 'пострадать': 1})),
#   ('произойти',
#    defaultdict(int,
#                {'negative': 58,
#                 'positive/negative': 2,
#                 'neutral': 5,
#                 'positive': 4}))],
#  '\n----\n',
#  [('принять', defaultdict(int, {'positive': 39, 'neutral': 4, 'negative': 5})),
#   ('обратить', defaultdict(int, {'positive': 64, 'negative': 2})),
#   ('стать',
#    defaultdict(int,
#                {'negative': 42,
#                 'positive': 35,
#                 'neutral': 18,
#                 'positive/negative': 3}))])

# %% [markdown]
# ## Синтаксический анализатор Stanza
#
# Одним из синтаксических анализаторов является [Stanza](https://stanfordnlp.github.io/stanza/installation_usage.html).

# %%
import stanza

# %%
nlp2 = stanza.Pipeline('ru', use_gpu=False)
# Out:
# 2023-05-12 09:02:32 INFO: Checking for updates to resources.json in case models have been updated.  Note: this behavior can be turned off with download_method=None or download_method=DownloadMethod.REUSE_RESOURCES
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/main/resources_1.4.1.json:   0%|   …
# 2023-05-12 09:02:34 INFO: Loading these models for language: ru (Russian):
# =========================
# | Processor | Package   |
# -------------------------
# | tokenize  | syntagrus |
# | pos       | syntagrus |
# | lemma     | syntagrus |
# | depparse  | syntagrus |
# | ner       | wikiner   |
# =========================
#
# 2023-05-12 09:02:34 INFO: Use device: cpu
# 2023-05-12 09:02:34 INFO: Loading: tokenize
# 2023-05-12 09:02:34 INFO: Loading: pos
# 2023-05-12 09:02:35 INFO: Loading: lemma
# 2023-05-12 09:02:35 INFO: Loading: depparse
# 2023-05-12 09:02:35 INFO: Loading: ner
# 2023-05-12 09:02:37 INFO: Done loading processors!

# %%
doc = nlp2(text_news[11])

# %%
doc.sentences[0].words
# Out:
# [{
#    "id": 1,
#    "text": "Ракета",
#    "lemma": "ракета",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing",
#    "head": 12,
#    "deprel": "nsubj",
#    "start_char": 0,
#    "end_char": 6
#  },
#  {
#    "id": 2,
#    "text": "-",
#    "lemma": "-",
#    "upos": "PUNCT",
#    "head": 3,
#    "deprel": "punct",
#    "start_char": 6,
#    "end_char": 7
#  },
#  {
#    "id": 3,
#    "text": "носитель",
#    "lemma": "носитель",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#    "head": 1,
#    "deprel": "appos",
#    "start_char": 7,
#    "end_char": 15
#  },
#  {
#    "id": 4,
#    "text": "«",
#    "lemma": "\"",
#    "upos": "PUNCT",
#    "head": 5,
#    "deprel": "punct",
#    "start_char": 16,
#    "end_char": 17
#  },
#  {
#    "id": 5,
#    "text": "Союз",
#    "lemma": "союз",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#    "head": 3,
#    "deprel": "appos",
#    "start_char": 17,
#    "end_char": 21
#  },
#  {
#    "id": 6,
#    "text": "-",
#    "lemma": "-",
#    "upos": "PUNCT",
#    "head": 7,
#    "deprel": "punct",
#    "start_char": 21,
#    "end_char": 22
#  },
#  {
#    "id": 7,
#    "text": "2.1а",
#    "lemma": "2.1",
#    "upos": "NUM",
#    "feats": "NumType=Card",
#    "head": 5,
#    "deprel": "nummod:entity",
#    "start_char": 22,
#    "end_char": 26
#  },
#  {
#    "id": 8,
#    "text": "»",
#    "lemma": "\"",
#    "upos": "PUNCT",
#    "head": 5,
#    "deprel": "punct",
#    "start_char": 26,
#    "end_char": 27
#  },
#  {
#    "id": 9,
#    "text": "с",
#    "lemma": "с",
#    "upos": "ADP",
#    "head": 11,
#    "deprel": "case",
#    "start_char": 28,
#    "end_char": 29
#  },
#  {
#    "id": 10,
#    "text": "11",
#    "lemma": "11",
#    "upos": "NUM",
#    "feats": "NumType=Card",
#    "head": 11,
#    "deprel": "nummod",
#    "start_char": 30,
#    "end_char": 32
#  },
#  {
#    "id": 11,
#    "text": "спутниками",
#    "lemma": "спутник",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur",
#    "head": 12,
#    "deprel": "obl",
#    "start_char": 33,
#    "end_char": 43
#  },
#  {
#    "id": 12,
#    "text": "стартовала",
#    "lemma": "стартовать",
#    "upos": "VERB",
#    "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#    "head": 0,
#    "deprel": "root",
#    "start_char": 44,
#    "end_char": 54
#  },
#  {
#    "id": 13,
#    "text": "с",
#    "lemma": "с",
#    "upos": "ADP",
#    "head": 14,
#    "deprel": "case",
#    "start_char": 55,
#    "end_char": 56
#  },
#  {
#    "id": 14,
#    "text": "космодрома",
#    "lemma": "космодром",
#    "upos": "NOUN",
#    "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#    "head": 12,
#    "deprel": "obl",
#    "start_char": 57,
#    "end_char": 67
#  },
#  {
#    "id": 15,
#    "text": "Восточный",
#    "lemma": "восточный",
#    "upos": "PROPN",
#    "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#    "head": 14,
#    "deprel": "appos",
#    "start_char": 68,
#    "end_char": 77
#  },
#  {
#    "id": 16,
#    "text": ".",
#    "lemma": ".",
#    "upos": "PUNCT",
#    "head": 12,
#    "deprel": "punct",
#    "start_char": 77,
#    "end_char": 78
#  }]

# %%
doc.sentences[0].words[0].lemma
# Out:
# 'ракета'

# %%
doc.sentences[0].dependencies
# Out:
# [({
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   },
#   'nsubj',
#   {
#     "id": 1,
#     "text": "Ракета",
#     "lemma": "ракета",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing",
#     "head": 12,
#     "deprel": "nsubj",
#     "start_char": 0,
#     "end_char": 6
#   }),
#  ({
#     "id": 3,
#     "text": "носитель",
#     "lemma": "носитель",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 1,
#     "deprel": "appos",
#     "start_char": 7,
#     "end_char": 15
#   },
#   'punct',
#   {
#     "id": 2,
#     "text": "-",
#     "lemma": "-",
#     "upos": "PUNCT",
#     "head": 3,
#     "deprel": "punct",
#     "start_char": 6,
#     "end_char": 7
#   }),
#  ({
#     "id": 1,
#     "text": "Ракета",
#     "lemma": "ракета",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing",
#     "head": 12,
#     "deprel": "nsubj",
#     "start_char": 0,
#     "end_char": 6
#   },
#   'appos',
#   {
#     "id": 3,
#     "text": "носитель",
#     "lemma": "носитель",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 1,
#     "deprel": "appos",
#     "start_char": 7,
#     "end_char": 15
#   }),
#  ({
#     "id": 5,
#     "text": "Союз",
#     "lemma": "союз",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 3,
#     "deprel": "appos",
#     "start_char": 17,
#     "end_char": 21
#   },
#   'punct',
#   {
#     "id": 4,
#     "text": "«",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "head": 5,
#     "deprel": "punct",
#     "start_char": 16,
#     "end_char": 17
#   }),
#  ({
#     "id": 3,
#     "text": "носитель",
#     "lemma": "носитель",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 1,
#     "deprel": "appos",
#     "start_char": 7,
#     "end_char": 15
#   },
#   'appos',
#   {
#     "id": 5,
#     "text": "Союз",
#     "lemma": "союз",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 3,
#     "deprel": "appos",
#     "start_char": 17,
#     "end_char": 21
#   }),
#  ({
#     "id": 7,
#     "text": "2.1а",
#     "lemma": "2.1",
#     "upos": "NUM",
#     "feats": "NumType=Card",
#     "head": 5,
#     "deprel": "nummod:entity",
#     "start_char": 22,
#     "end_char": 26
#   },
#   'punct',
#   {
#     "id": 6,
#     "text": "-",
#     "lemma": "-",
#     "upos": "PUNCT",
#     "head": 7,
#     "deprel": "punct",
#     "start_char": 21,
#     "end_char": 22
#   }),
#  ({
#     "id": 5,
#     "text": "Союз",
#     "lemma": "союз",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 3,
#     "deprel": "appos",
#     "start_char": 17,
#     "end_char": 21
#   },
#   'nummod:entity',
#   {
#     "id": 7,
#     "text": "2.1а",
#     "lemma": "2.1",
#     "upos": "NUM",
#     "feats": "NumType=Card",
#     "head": 5,
#     "deprel": "nummod:entity",
#     "start_char": 22,
#     "end_char": 26
#   }),
#  ({
#     "id": 5,
#     "text": "Союз",
#     "lemma": "союз",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 3,
#     "deprel": "appos",
#     "start_char": 17,
#     "end_char": 21
#   },
#   'punct',
#   {
#     "id": 8,
#     "text": "»",
#     "lemma": "\"",
#     "upos": "PUNCT",
#     "head": 5,
#     "deprel": "punct",
#     "start_char": 26,
#     "end_char": 27
#   }),
#  ({
#     "id": 11,
#     "text": "спутниками",
#     "lemma": "спутник",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 33,
#     "end_char": 43
#   },
#   'case',
#   {
#     "id": 9,
#     "text": "с",
#     "lemma": "с",
#     "upos": "ADP",
#     "head": 11,
#     "deprel": "case",
#     "start_char": 28,
#     "end_char": 29
#   }),
#  ({
#     "id": 11,
#     "text": "спутниками",
#     "lemma": "спутник",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 33,
#     "end_char": 43
#   },
#   'nummod',
#   {
#     "id": 10,
#     "text": "11",
#     "lemma": "11",
#     "upos": "NUM",
#     "feats": "NumType=Card",
#     "head": 11,
#     "deprel": "nummod",
#     "start_char": 30,
#     "end_char": 32
#   }),
#  ({
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   },
#   'obl',
#   {
#     "id": 11,
#     "text": "спутниками",
#     "lemma": "спутник",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Ins|Gender=Masc|Number=Plur",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 33,
#     "end_char": 43
#   }),
#  ({
#     "id": 0,
#     "text": "ROOT"
#   },
#   'root',
#   {
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   }),
#  ({
#     "id": 14,
#     "text": "космодрома",
#     "lemma": "космодром",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 57,
#     "end_char": 67
#   },
#   'case',
#   {
#     "id": 13,
#     "text": "с",
#     "lemma": "с",
#     "upos": "ADP",
#     "head": 14,
#     "deprel": "case",
#     "start_char": 55,
#     "end_char": 56
#   }),
#  ({
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   },
#   'obl',
#   {
#     "id": 14,
#     "text": "космодрома",
#     "lemma": "космодром",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 57,
#     "end_char": 67
#   }),
#  ({
#     "id": 14,
#     "text": "космодрома",
#     "lemma": "космодром",
#     "upos": "NOUN",
#     "feats": "Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing",
#     "head": 12,
#     "deprel": "obl",
#     "start_char": 57,
#     "end_char": 67
#   },
#   'appos',
#   {
#     "id": 15,
#     "text": "Восточный",
#     "lemma": "восточный",
#     "upos": "PROPN",
#     "feats": "Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing",
#     "head": 14,
#     "deprel": "appos",
#     "start_char": 68,
#     "end_char": 77
#   }),
#  ({
#     "id": 12,
#     "text": "стартовала",
#     "lemma": "стартовать",
#     "upos": "VERB",
#     "feats": "Aspect=Perf|Gender=Fem|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin|Voice=Act",
#     "head": 0,
#     "deprel": "root",
#     "start_char": 44,
#     "end_char": 54
#   },
#   'punct',
#   {
#     "id": 16,
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "head": 12,
#     "deprel": "punct",
#     "start_char": 77,
#     "end_char": 78
#   })]

# %%
# Поиск эмоционально окрашенных потомков для Stanza.
def find_sentiments_stanza(dependencies, senti_words, sentiments):
    for dep in dependencies:
        if dep[2].lemma in senti_words.keys():
            if dep[0].lemma not in sentiments.keys():
                sentiments[dep[0].lemma] = defaultdict(int)
            sentiments[dep[0].lemma][senti_words[dep[2].lemma]] += 1

# %%
sentiments = {}

for news1 in tqdm(text_news):
    doc = nlp2(news1)

    for sentence in doc.sentences:
        find_sentiments_stanza(sentence.dependencies, senti_words, sentiments)
# Out:
# 100%|███████████████████████████████████████| 1708/1708 [46:38<00:00,  1.64s/it]

# %%
sentiments
# Out:
# {'комплект': defaultdict(int, {'neutral': 1}),
#  'провести': defaultdict(int, {'neutral': 20, 'negative': 3, 'positive': 4}),
#  'являться': defaultdict(int,
#              {'neutral': 8,
#               'positive': 18,
#               'negative': 24,
#               'positive/negative': 2}),
#  'в': defaultdict(int, {'neutral': 34, 'positive': 9, 'negative': 4}),
#  'головка': defaultdict(int, {'positive': 1}),
#  'отсутствовать': defaultdict(int, {'positive': 2}),
#  'порядок': defaultdict(int, {'positive': 1, 'neutral': 3, 'negative': 2}),
#  'аппаратура': defaultdict(int, {'positive': 1}),
#  'уделяться': defaultdict(int, {'positive': 2}),
#  'Совет': defaultdict(int, {'positive': 11}),
#  'способный': defaultdict(int,
#              {'positive/negative': 4, 'negative': 6, 'neutral': 2}),
#  'сдерживание': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'выразить': defaultdict(int, {'positive': 13, 'negative': 29, 'neutral': 1}),
#  None: defaultdict(int,
#              {'positive': 689,
#               'negative': 757,
#               'neutral': 117,
#               'positive/negative': 86}),
#  'молеться': defaultdict(int, {'positive': 1}),
#  'покорить': defaultdict(int, {'negative': 1}),
#  'повстречаться': defaultdict(int, {'negative': 1}),
#  'нраво': defaultdict(int, {'positive': 1}),
#  'становиться': defaultdict(int, {'negative': 5, 'positive': 6, 'neutral': 6}),
#  'пинать': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'демонстрировать': defaultdict(int,
#              {'positive': 9, 'negative': 3, 'neutral': 1}),
#  'культура': defaultdict(int,
#              {'negative': 1, 'positive': 1, 'positive/negative': 1}),
#  'обрести': defaultdict(int, {'positive': 5}),
#  'знание': defaultdict(int, {'neutral': 1, 'negative': 1}),
#  'стиль': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'аouэubеблогер': defaultdict(int, {'positive': 2}),
#  'владение': defaultdict(int, {'neutral': 1}),
#  'результат': defaultdict(int,
#              {'negative': 29,
#               'neutral': 9,
#               'positive': 21,
#               'positive/negative': 3}),
#  'травма': defaultdict(int,
#              {'positive': 4,
#               'negative': 4,
#               'positive/negative': 1,
#               'neutral': 1}),
#  'получить': defaultdict(int,
#              {'negative': 60,
#               'positive': 31,
#               'neutral': 6,
#               'positive/negative': 4}),
#  'почувствовать': defaultdict(int, {'negative': 5, 'positive': 1}),
#  'оказывать': defaultdict(int, {'positive': 3, 'negative': 4, 'neutral': 1}),
#  'сойти': defaultdict(int, {'negative': 1}),
#  'уточнить': defaultdict(int,
#              {'positive/negative': 3, 'positive': 2, 'negative': 3}),
#  'страдать': defaultdict(int,
#              {'negative': 30, 'neutral': 4, 'positive/negative': 2}),
#  'разрыть': defaultdict(int, {'negative': 1}),
#  'один': defaultdict(int, {'neutral': 6, 'negative': 24, 'positive': 27}),
#  'аренда': defaultdict(int, {'neutral': 1}),
#  'шлем': defaultdict(int, {'positive': 1}),
#  'роботыИздание': defaultdict(int, {'positive/negative': 1}),
#  'указать': defaultdict(int,
#              {'positive/negative': 1, 'positive': 2, 'negative': 4}),
#  'запретить': defaultdict(int, {'negative': 7, 'positive': 2}),
#  'намерение': defaultdict(int, {'positive': 4, 'negative': 2}),
#  'принять': defaultdict(int, {'positive': 84, 'negative': 8, 'neutral': 36}),
#  'импонировать': defaultdict(int, {'positive': 1}),
#  'планировать': defaultdict(int,
#              {'opinion\n': 1, 'neutral': 2, 'positive': 6, 'negative': 4}),
#  'обратить': defaultdict(int, {'positive': 83, 'neutral': 4, 'negative': 3}),
#  'норма': defaultdict(int, {'positive/negative': 1, 'positive': 4}),
#  'радоваться': defaultdict(int, {'positive': 2}),
#  'повод': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'опрос': defaultdict(int, {'positive': 2}),
#  'превышать': defaultdict(int, {'negative': 4, 'positive': 1}),
#  'работать': defaultdict(int,
#              {'negative': 6,
#               'neutral': 2,
#               'positive': 4,
#               'positive/negative': 1}),
#  'подлежать': defaultdict(int, {'negative': 3}),
#  'стать': defaultdict(int,
#              {'negative': 89,
#               'positive': 55,
#               'neutral': 34,
#               'positive/negative': 7}),
#  'техника': defaultdict(int, {'negative': 3, 'positive': 6}),
#  'признать': defaultdict(int, {'negative': 69, 'positive': 16, 'neutral': 3}),
#  'оборот': defaultdict(int, {'negative': 8}),
#  'лишение': defaultdict(int, {'positive/negative': 1, 'negative': 3}),
#  'приговор': defaultdict(int, {'positive': 3, 'negative': 5}),
#  'выносить': defaultdict(int, {'negative': 3}),
#  'товар': defaultdict(int, {'positive': 4, 'neutral': 1}),
#  'увеличение': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'улучшение': defaultdict(int, {'positive': 3, 'neutral': 2}),
#  'материал': defaultdict(int, {'negative': 37, 'positive': 8, 'neutral': 6}),
#  'дом': defaultdict(int,
#              {'positive': 20, 'negative': 4, 'positive/negative': 1}),
#  'вода': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'температура': defaultdict(int, {'neutral': 5}),
#  'вызывать': defaultdict(int, {'negative': 26, 'positive': 5, 'neutral': 1}),
#  'находиться': defaultdict(int,
#              {'negative': 41,
#               'positive': 7,
#               'positive/negative': 3,
#               'neutral': 4}),
#  'фаза': defaultdict(int, {'positive': 2, 'neutral': 2}),
#  'сигнал': defaultdict(int, {'negative': 3, 'positive': 1, 'neutral': 1}),
#  'жилет': defaultdict(int, {'negative': 1}),
#  'домогательство': defaultdict(int,
#              {'positive/negative': 25, 'negative': 6, 'neutral': 1}),
#  'обвинить': defaultdict(int, {'negative': 41, 'positive': 3, 'neutral': 1}),
#  'школа': defaultdict(int, {'neutral': 5, 'negative': 1}),
#  'сообщить': defaultdict(int,
#              {'пострадать': 1,
#               'negative': 23,
#               'positive': 16,
#               'neutral': 5,
#               'positive/negative': 3}),
#  'наставник': defaultdict(int, {'positive': 2}),
#  'принадлежать': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'обнаружить': defaultdict(int,
#              {'пострадать': 1, 'negative': 18, 'positive': 6, 'neutral': 4}),
#  'арестовывать': defaultdict(int,
#              {'neutral': 4, 'negative': 12, 'positive': 1}),
#  'обвинение': defaultdict(int,
#              {'negative': 29,
#               'positive': 3,
#               'neutral': 2,
#               'positive/negative': 1}),
#  'предъявить': defaultdict(int, {'neutral': 32, 'positive/negative': 1}),
#  'обращение': defaultdict(int, {'positive': 2, 'negative': 11}),
#  'блюдо': defaultdict(int, {'positive': 2}),
#  'вариант': defaultdict(int, {'positive': 3, 'neutral': 1, 'negative': 1}),
#  'ребенок': defaultdict(int, {'positive': 2, 'negative': 12, 'neutral': 4}),
#  'любить': defaultdict(int, {'positive': 3, 'negative': 1, 'neutral': 1}),
#  'популярный': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'пицца': defaultdict(int, {'negative': 1, 'neutral': 2}),
#  'должен': defaultdict(int,
#              {'positive': 28,
#               'neutral': 5,
#               'negative': 14,
#               'positive/negative': 2}),
#  'мультсериал': defaultdict(int, {'positive': 1}),
#  'серия': defaultdict(int,
#              {'positive': 2,
#               'negative': 12,
#               'neutral': 5,
#               'positive/negative': 2}),
#  'история': defaultdict(int, {'negative': 14, 'positive': 8}),
#  'писать': defaultdict(int,
#              {'negative': 10, 'positive': 9, 'positive/negative': 1}),
#  'теме20': defaultdict(int, {'negative': 1}),
#  'мочь': defaultdict(int,
#              {'negative': 81,
#               'positive': 55,
#               'positive/negative': 8,
#               'neutral': 19}),
#  'понести': defaultdict(int, {'positive': 3, 'negative': 7}),
#  'ответственность': defaultdict(int,
#              {'negative': 21,
#               'positive/negative': 1,
#               'positive': 9,
#               'neutral': 1}),
#  'лопаться': defaultdict(int, {'positive': 2}),
#  'брать': defaultdict(int,
#              {'negative': 5, 'positive': 30, 'positive/negative': 2}),
#  'неспособный': defaultdict(int, {'negative': 1}),
#  'наказывать': defaultdict(int, {'negative': 3}),
#  'коллаборационист': defaultdict(int, {'negative': 1}),
#  'навеять': defaultdict(int, {'negative': 1}),
#  'бегство': defaultdict(int, {'negative': 1}),
#  'дело': defaultdict(int, {'negative': 156, 'neutral': 1, 'positive': 6}),
#  'угрожать': defaultdict(int, {'negative': 6, 'positive': 1, 'neutral': 1}),
#  'задержать': defaultdict(int, {'negative': 26, 'neutral': 4}),
#  'совершение': defaultdict(int,
#              {'negative': 13, 'positive/negative': 1, 'neutral': 2}),
#  'киевлянин': defaultdict(int, {'negative': 1}),
#  'акция': defaultdict(int, {'negative': 12, 'positive': 1, 'neutral': 1}),
#  'участвовать': defaultdict(int, {'neutral': 5, 'negative': 2, 'positive': 2}),
#  'трансляция': defaultdict(int, {'positive': 4}),
#  'завершиться': defaultdict(int,
#              {'negative': 2, 'positive': 8, 'positive/negative': 2}),
#  'объяснить': defaultdict(int, {'negative': 8, 'positive': 3, 'neutral': 2}),
#  'заявить': defaultdict(int,
#              {'negative': 35,
#               'positive': 28,
#               'neutral': 10,
#               'positive/negative': 1}),
#  'запуск': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'дизайнер': defaultdict(int, {'negative': 1, 'positive': 3, 'neutral': 1}),
#  'известный': defaultdict(int, {'neutral': 2, 'positive': 2, 'negative': 4}),
#  'расследование': defaultdict(int, {'negative': 18, 'positive/negative': 1}),
#  'умереть': defaultdict(int,
#              {'negative': 4, 'neutral': 1, 'positive/negative': 1}),
#  'войныпервоначально': defaultdict(int, {'positive': 1}),
#  'Гей-деревни': defaultdict(int, {'neutral': 1}),
#  'два': defaultdict(int, {'neutral': 1}),
#  'убийца': defaultdict(int, {'negative': 3, 'neutral': 2}),
#  'оказаться': defaultdict(int,
#              {'neutral': 7,
#               'negative': 25,
#               'positive': 28,
#               'positive/negative': 3}),
#  'считать': defaultdict(int,
#              {'negative': 39,
#               'positive': 16,
#               'neutral': 3,
#               'positive/negative': 4}),
#  'выбирать': defaultdict(int, {'negative': 1}),
#  'тест': defaultdict(int, {'neutral': 2, 'positive': 1}),
#  'потерпеть': defaultdict(int,
#              {'negative': 22, 'positive/negative': 7, 'positive': 2}),
#  'проводить': defaultdict(int,
#              {'neutral': 13,
#               'positive': 5,
#               'negative': 2,
#               'positive/negative': 1}),
#  'защита': defaultdict(int,
#              {'negative': 6,
#               'positive': 6,
#               'neutral': 5,
#               'positive/negative': 2}),
#  'отличать': defaultdict(int, {'positive/negative': 1}),
#  'видео': defaultdict(int,
#              {'positive': 13,
#               'negative': 23,
#               'positive/negative': 2,
#               'neutral': 1}),
#  'страна': defaultdict(int,
#              {'neutral': 10,
#               'positive': 3,
#               'positive/negative': 1,
#               'negative': 3}),
#  'признавать': defaultdict(int, {'positive': 6, 'neutral': 2, 'negative': 14}),
#  'персона': defaultdict(int, {'positive': 1}),
#  'питание': defaultdict(int, {'positive': 2, 'neutral': 1, 'negative': 1}),
#  'еда': defaultdict(int, {'positive': 3, 'negative': 1}),
#  'кусок': defaultdict(int, {'neutral': 1, 'positive': 1}),
#  'жир': defaultdict(int, {'positive': 2}),
#  'назвать': defaultdict(int,
#              {'positive': 30,
#               'negative': 40,
#               'positive/negative': 5,
#               'neutral': 8}),
#  'выбор': defaultdict(int, {'positive': 2}),
#  'добавка': defaultdict(int, {'negative': 1}),
#  'процесс': defaultdict(int, {'negative': 8, 'neutral': 4}),
#  'прийти': defaultdict(int,
#              {'neutral': 1,
#               'positive/negative': 1,
#               'positive': 6,
#               'negative': 7}),
#  'ускорить': defaultdict(int, {'negative': 1}),
#  'начинаться': defaultdict(int, {'neutral': 2}),
#  'вызвать': defaultdict(int,
#              {'neutral': 9,
#               'negative': 28,
#               'positive/negative': 2,
#               'positive': 6}),
#  'омег': defaultdict(int, {'positive': 1}),
#  'кислота': defaultdict(int, {'neutral': 3}),
#  'продукт': defaultdict(int, {'positive': 9, 'negative': 1}),
#  'заболевание': defaultdict(int, {'positive': 2, 'negative': 8, 'neutral': 4}),
#  'предотвращать': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'функция': defaultdict(int, {'positive': 1, 'negative': 1, 'neutral': 2}),
#  'защищать': defaultdict(int,
#              {'negative': 4, 'positive/negative': 2, 'positive': 1}),
#  'накопление': defaultdict(int, {'negative': 2, 'positive/negative': 1}),
#  'часть': defaultdict(int,
#              {'negative': 5,
#               'positive/negative': 2,
#               'positive': 14,
#               'neutral': 4}),
#  'анализировать': defaultdict(int, {'positive': 3, 'neutral': 2}),
#  'область': defaultdict(int, {'neutral': 2, 'negative': 3, 'positive': 8}),
#  'ткань': defaultdict(int, {'neutral': 1, 'negative': 4, 'positive': 1}),
#  'маркер': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'усиливать': defaultdict(int, {'negative': 1, 'positive': 2}),
#  'влиять': defaultdict(int,
#              {'positive': 6,
#               'positive/negative': 1,
#               'neutral': 2,
#               'negative': 3}),
#  'вернуться': defaultdict(int, {'negative': 5, 'positive': 1}),
#  'директор': defaultdict(int, {'positive': 11, 'neutral': 1}),
#  'туалет': defaultdict(int, {'negative': 1}),
#  'подать': defaultdict(int, {'negative': 24, 'positive': 2, 'neutral': 2}),
#  'выступать': defaultdict(int,
#              {'neutral': 3,
#               'positive': 5,
#               'negative': 2,
#               'positive/negative': 1}),
#  'условие': defaultdict(int, {'neutral': 12, 'positive': 12, 'negative': 5}),
#  'соперник': defaultdict(int, {'positive': 1}),
#  'проблема': defaultdict(int,
#              {'positive/negative': 1,
#               'negative': 11,
#               'positive': 9,
#               'neutral': 1}),
#  'связать': defaultdict(int,
#              {'neutral': 2,
#               'negative': 20,
#               'positive': 8,
#               'positive/negative': 2}),
#  'устранить': defaultdict(int, {'negative': 6, 'neutral': 3}),
#  'причина': defaultdict(int,
#              {'neutral': 6,
#               'negative': 47,
#               'positive/negative': 3,
#               'positive': 5}),
#  'маскироваться': defaultdict(int, {'negative': 1}),
#  'вид': defaultdict(int, {'negative': 9, 'neutral': 13, 'positive': 5}),
#  'услуга': defaultdict(int, {'negative': 1, 'positive/negative': 1}),
#  'второй': defaultdict(int, {'positive': 6, 'neutral': 1}),
#  'наносить': defaultdict(int, {'negative': 15}),
#  'запугивание': defaultdict(int, {'negative': 1}),
#  'контент': defaultdict(int, {'negative': 12, 'positive/negative': 1}),
#  'ролик': defaultdict(int, {'positive': 11, 'negative': 11, 'neutral': 3}),
#  'обещать': defaultdict(int, {'negative': 3, 'positive': 4, 'neutral': 2}),
#  'оставить': defaultdict(int, {'neutral': 1, 'positive': 6, 'negative': 6}),
#  'объяснять': defaultdict(int, {'positive': 1, 'negative': 6, 'neutral': 2}),
#  'положение': defaultdict(int, {'neutral': 1, 'positive': 1, 'negative': 3}),
#  'делать': defaultdict(int,
#              {'negative': 22,
#               'positive': 21,
#               'positive/negative': 3,
#               'neutral': 12}),
#  'мишень': defaultdict(int, {'positive': 1}),
#  'подстегнуть': defaultdict(int, {'negative': 1}),
#  'сайт': defaultdict(int, {'positive': 1, 'negative': 5, 'neutral': 1}),
#  'возможный': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'обойти': defaultdict(int,
#              {'neutral': 1, 'positive/negative': 1, 'negative': 3}),
#  'ловушка': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'ошибка': defaultdict(int,
#              {'negative': 1, 'positive/negative': 1, 'positive': 1}),
#  'привести': defaultdict(int,
#              {'negative': 32,
#               'positive': 10,
#               'neutral': 1,
#               'positive/negative': 2}),
#  'последствие': defaultdict(int, {'negative': 7, 'positive': 2, 'neutral': 5}),
#  'перехват': defaultdict(int, {'negative': 1}),
#  'допускать': defaultdict(int, {'negative': 2}),
#  'прекратить': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'Фонд': defaultdict(int, {'positive': 4}),
#  'предусмотреть': defaultdict(int,
#              {'positive': 3,
#               'positive/negative': 1,
#               'negative': 3,
#               'neutral': 1}),
#  'фонд': defaultdict(int, {'positive': 2}),
#  'подушка': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'финансирование': defaultdict(int, {'negative': 6}),
#  'случай': defaultdict(int,
#              {'positive/negative': 1,
#               'negative': 35,
#               'positive': 6,
#               'neutral': 3}),
#  'факт': defaultdict(int, {'negative': 20, 'positive': 4, 'neutral': 3}),
#  'отмывание': defaultdict(int, {'negative': 2}),
#  'атлетика': defaultdict(int, {'positive': 2}),
#  'компания': defaultdict(int,
#              {'positive': 5, 'positive/negative': 2, 'negative': 1}),
#  'схема': defaultdict(int, {'negative': 5, 'positive': 2, 'neutral': 1}),
#  'выплата': defaultdict(int, {'negative': 1, 'neutral': 1}),
#  'скрывать': defaultdict(int, {'negative': 5}),
#  'терпеть': defaultdict(int, {'negative': 3}),
#  'начальница': defaultdict(int, {'negative': 1}),
#  'выдерживать': defaultdict(int, {'positive': 1}),
#  'начинать': defaultdict(int, {'negative': 4, 'positive': 2, 'neutral': 1}),
#  'выражение': defaultdict(int, {'negative': 3}),
#  'поза': defaultdict(int, {'negative': 1, 'neutral': 2, 'positive': 2}),
#  'снимок': defaultdict(int, {'positive': 5, 'negative': 3}),
#  'набрать': defaultdict(int, {'positive': 2}),
#  'боль': defaultdict(int, {'negative': 4, 'positive/negative': 2}),
#  'видеть': defaultdict(int, {'negative': 13, 'positive': 9, 'neutral': 7}),
#  'данные': defaultdict(int, {'positive': 2, 'negative': 5, 'neutral': 6}),
#  'преступление': defaultdict(int,
#              {'neutral': 1, 'negative': 16, 'positive': 1}),
#  'деяние': defaultdict(int, {'negative': 1}),
#  'число': defaultdict(int, {'negative': 10, 'neutral': 3, 'positive': 8}),
#  'тысяча': defaultdict(int, {'negative': 6}),
#  'количество': defaultdict(int, {'negative': 10, 'neutral': 8, 'positive': 3}),
#  'совершать': defaultdict(int,
#              {'negative': 5,
#               'positive': 3,
#               'positive/negative': 3,
#               'neutral': 1}),
#  'уровень': defaultdict(int, {'neutral': 8, 'negative': 8, 'positive': 11}),
#  'малый': defaultdict(int, {'negative': 1, 'neutral': 8}),
#  'аттестат': defaultdict(int, {'positive': 1}),
#  'образование': defaultdict(int, {'neutral': 1, 'positive': 2, 'negative': 3}),
#  'ракета': defaultdict(int, {'positive': 10, 'neutral': 2, 'negative': 9}),
#  'сообщаться': defaultdict(int, {'positive': 1}),
#  'подробность': defaultdict(int,
#              {'positive': 3, 'negative': 10, 'neutral': 3}),
#  'хранить': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'деятельность': defaultdict(int,
#              {'negative': 38, 'positive': 6, 'neutral': 1}),
#  'завод': defaultdict(int, {'negative': 1}),
#  'опубликовать': defaultdict(int,
#              {'negative': 2, 'positive': 7, 'neutral': 1}),
#  'отбить': defaultdict(int, {'neutral': 1, 'negative': 1, 'positive': 1}),
#  'контролировать': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'место': defaultdict(int,
#              {'positive': 10,
#               'neutral': 6,
#               'negative': 34,
#               'positive/negative': 14}),
#  'уйти': defaultdict(int,
#              {'positive': 3,
#               'negative': 4,
#               'neutral': 1,
#               'positive/negative': 1}),
#  'Джабхат': defaultdict(int, {'negative': 10}),
#  'бой': defaultdict(int, {'negative': 7, 'positive': 4}),
#  'ответ': defaultdict(int,
#              {'positive': 6,
#               'negative': 2,
#               'positive/negative': 1,
#               'neutral': 1}),
#  'задачка': defaultdict(int, {'positive': 3, 'negative': 3}),
#  'счесть': defaultdict(int, {'positive': 5, 'negative': 14, 'neutral': 2}),
#  'вес': defaultdict(int, {'neutral': 10, 'positive': 5, 'negative': 2}),
#  'приблизиться': defaultdict(int, {'negative': 1}),
#  'спор': defaultdict(int, {'positive': 2}),
#  'намекнуть': defaultdict(int, {'negative': 1}),
#  'мышление': defaultdict(int, {'neutral': 1, 'positive': 3}),
#  'огорчиться': defaultdict(int, {'negative': 1}),
#  'извинение': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'просить': defaultdict(int, {'negative': 5, 'positive': 21, 'neutral': 2}),
#  'то': defaultdict(int,
#              {'negative': 36,
#               'positive': 29,
#               'positive/negative': 2,
#               'neutral': 5}),
#  'ужасный': defaultdict(int, {'negative': 1}),
#  'политик': defaultdict(int, {'negative': 1}),
#  'рассказать': defaultdict(int,
#              {'negative': 36,
#               'neutral': 5,
#               'positive': 17,
#               'positive/negative': 5}),
#  'трусы': defaultdict(int, {'neutral': 1}),
#  'котомомент': defaultdict(int, {'positive': 1}),
#  'доказать': defaultdict(int, {'positive': 6, 'negative': 5, 'neutral': 1}),
#  'наклонность': defaultdict(int, {'negative': 2}),
#  'ходить': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'сосед': defaultdict(int, {'negative': 2}),
#  'Петербург': defaultdict(int, {'negative': 2}),
#  'дискуссия': defaultdict(int, {'negative': 2, 'positive': 3}),
#  'сериал': defaultdict(int, {'negative': 4, 'positive': 2, 'neutral': 1}),
#  'человек': defaultdict(int, {'positive': 28, 'neutral': 5, 'negative': 21}),
#  'пропаганда': defaultdict(int, {'negative': 6, 'positive': 1}),
#  'бандитизм': defaultdict(int, {'negative': 1}),
#  'подчеркнуть': defaultdict(int,
#              {'positive': 10,
#               'positive/negative': 1,
#               'negative': 3,
#               'neutral': 1}),
#  'фильм': defaultdict(int,
#              {'negative': 18, 'positive': 9, 'positive/negative': 2}),
#  'пропагандировать': defaultdict(int, {'negative': 1}),
#  'убиватьскать': defaultdict(int, {'negative': 1}),
#  'урок': defaultdict(int, {'negative': 1, 'positive': 5}),
#  'бригада': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'огнемет': defaultdict(int, {'positive': 3}),
#  'включить': defaultdict(int, {'neutral': 1, 'negative': 2, 'positive': 2}),
#  'оружие': defaultdict(int,
#              {'negative': 9, 'positive': 7, 'positive/negative': 1}),
#  'огнетушитель': defaultdict(int, {'positive': 1}),
#  'контейнер': defaultdict(int, {'positive': 1, 'negative': 3}),
#  'кормить': defaultdict(int, {'negative': 8, 'positive': 1}),
#  'модель': defaultdict(int, {'neutral': 5, 'positive': 5, 'negative': 2}),
#  'образец': defaultdict(int, {'neutral': 2, 'positive': 2}),
#  'вскрыть': defaultdict(int, {'negative': 1}),
#  'заявлять': defaultdict(int, {'negative': 5, 'neutral': 5, 'positive': 6}),
#  'убить': defaultdict(int, {'positive': 7, 'negative': 10}),
#  'ИГ': defaultdict(int, {'negative': 32}),
#  'готовить': defaultdict(int, {'negative': 4, 'neutral': 1}),
#  'оператор': defaultdict(int, {'negative': 1}),
#  'оказать': defaultdict(int, {'negative': 10, 'positive': 16}),
#  'устройство': defaultdict(int, {'negative': 8, 'neutral': 1, 'positive': 1}),
#  'организация': defaultdict(int, {'negative': 29, 'positive': 18}),
#  'акт': defaultdict(int, {'negative': 7, 'positive/negative': 2}),
#  'теракт': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'страхование': defaultdict(int, {'positive': 5}),
#  'забрать': defaultdict(int, {'positive': 3, 'negative': 5}),
#  'объявление': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'рамка': defaultdict(int, {'negative': 3, 'positive': 3}),
#  'совершить': defaultdict(int, {'negative': 23, 'neutral': 2, 'positive': 2}),
#  'треть': defaultdict(int, {'positive/negative': 1, 'negative': 1}),
#  'оспаривать': defaultdict(int, {'positive/negative': 1}),
#  'вынести': defaultdict(int, {'positive': 2, 'negative': 6}),
#  'сказать': defaultdict(int,
#              {'positive': 13,
#               'negative': 9,
#               'positive/negative': 2,
#               'neutral': 2}),
#  'касаться': defaultdict(int, {'positive': 2, 'negative': 3}),
#  'сумма': defaultdict(int, {'positive': 4, 'neutral': 3, 'negative': 4}),
#  'дата': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'неплатежеспособность': defaultdict(int, {'neutral': 1}),
#  'состояние': defaultdict(int,
#              {'negative': 15,
#               'positive/negative': 8,
#               'positive': 5,
#               'neutral': 2}),
#  'рост': defaultdict(int,
#              {'positive': 12,
#               'positive/negative': 6,
#               'negative': 6,
#               'neutral': 2}),
#  'задействовать': defaultdict(int,
#              {'neutral': 8, 'positive': 1, 'negative': 1}),
#  'БМП': defaultdict(int,
#              {'neutral': 1, 'positive': 1, 'positive/negative': 1}),
#  'пойти': defaultdict(int, {'neutral': 1, 'negative': 6, 'positive': 4}),
#  'дорогой': defaultdict(int, {'neutral': 1, 'positive': 2}),
#  'сложный': defaultdict(int,
#              {'neutral': 1,
#               'positive': 7,
#               'negative': 2,
#               'positive/negative': 1}),
#  'расти': defaultdict(int, {'positive': 2, 'positive/negative': 1}),
#  'аннулировать': defaultdict(int,
#              {'positive': 7, 'positive/negative': 7, 'negative': 2}),
#  'участие': defaultdict(int, {'negative': 24, 'positive': 9, 'neutral': 4}),
#  'список': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'подтвердить': defaultdict(int, {'neutral': 2, 'positive': 7, 'negative': 7}),
#  'виновный': defaultdict(int, {'negative': 18, 'neutral': 1}),
#  'отстранение': defaultdict(int, {'negative': 2, 'positive': 7, 'neutral': 1}),
#  'запрет': defaultdict(int, {'positive': 6, 'neutral': 2, 'negative': 1}),
#  'общаться': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'Игра': defaultdict(int, {'negative': 2}),
#  'отстранить': defaultdict(int, {'positive': 22, 'negative': 8}),
#  'пользоваться': defaultdict(int, {'negative': 1, 'positive': 7}),
#  'самолет': defaultdict(int, {'negative': 6, 'positive': 5}),
#  'погибнуть': defaultdict(int,
#              {'negative': 30,
#               'positive': 4,
#               'positive/negative': 1,
#               'neutral': 7}),
#  'просьба': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'купить': defaultdict(int, {'negative': 4}),
#  'горе': defaultdict(int, {'positive': 1}),
#  'нажиться': defaultdict(int, {'negative': 1, 'positive/negative': 1}),
#  'ущерб': defaultdict(int, {'positive': 9}),
#  'причинение': defaultdict(int, {'negative': 17}),
#  'родственник': defaultdict(int, {'negative': 11, 'positive': 4}),
#  'привлекать': defaultdict(int, {'positive': 6, 'negative': 1}),
#  'выжить': defaultdict(int, {'negative': 4, 'neutral': 1}),
#  'сотрясение': defaultdict(int, {'positive': 1}),
#  'технология': defaultdict(int, {'negative': 2, 'positive': 9, 'neutral': 1}),
#  'пригодный': defaultdict(int, {'negative': 1}),
#  'орбита': defaultdict(int, {'neutral': 13, 'negative': 1}),
#  'спутник': defaultdict(int, {'negative': 2, 'neutral': 3}),
#  'уязвимый': defaultdict(int, {'positive': 2, 'positive/negative': 1}),
#  'лагерь': defaultdict(int, {'negative': 3}),
#  'год': defaultdict(int,
#              {'neutral': 17,
#               'negative': 47,
#               'positive/negative': 2,
#               'positive': 2}),
#  'надо': defaultdict(int, {'negative': 8, 'positive': 5}),
#  'подготовить': defaultdict(int, {'negative': 7, 'positive': 2}),
#  'идеология': defaultdict(int, {'negative': 3}),
#  'отрицание': defaultdict(int, {'negative': 5, 'positive': 5}),
#  'помогать': defaultdict(int, {'negative': 7, 'positive': 5, 'neutral': 1}),
#  'освободить': defaultdict(int, {'neutral': 1, 'positive': 3, 'negative': 3}),
#  'реагировать': defaultdict(int, {'positive': 1, 'neutral': 3, 'negative': 1}),
#  'дебаты': defaultdict(int, {'negative': 1}),
#  'роль': defaultdict(int, {'negative': 3, 'positive': 7, 'neutral': 4}),
#  'Германия': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'жить': defaultdict(int, {'negative': 4, 'positive': 1}),
#  'строить': defaultdict(int, {'negative': 1, 'positive': 1, 'neutral': 2}),
#  'территория': defaultdict(int, {'negative': 14}),
#  'рука': defaultdict(int, {'negative': 5, 'positive': 5}),
#  'тварь': defaultdict(int, {'positive': 5}),
#  'снять': defaultdict(int,
#              {'negative': 13,
#               'neutral': 10,
#               'positive': 3,
#               'positive/negative': 3}),
#  'форма': defaultdict(int, {'neutral': 2, 'negative': 7, 'positive': 5}),
#  'идея': defaultdict(int, {'positive': 3, 'negative': 2}),
#  'друг': defaultdict(int, {'positive': 25, 'negative': 1}),
#  'вольнодумец': defaultdict(int, {'negative': 1}),
#  'преподаватель': defaultdict(int, {'positive': 1}),
#  'пара': defaultdict(int, {'positive': 4}),
#  'поклонник': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'ориентация': defaultdict(int, {'positive/negative': 7, 'positive': 1}),
#  'раскрывать': defaultdict(int, {'positive': 4}),
#  'представитель': defaultdict(int,
#              {'neutral': 3, 'negative': 3, 'positive': 4}),
#  'спин-офф': defaultdict(int, {'negative': 1}),
#  'дереть': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'служба': defaultdict(int, {'positive': 13, 'negative': 6}),
#  'вынудить': defaultdict(int, {'negative': 1, 'positive': 2}),
#  'скончаться': defaultdict(int, {'negative': 6, 'positive/negative': 1}),
#  'произойти': defaultdict(int,
#              {'negative': 88,
#               'neutral': 9,
#               'positive/negative': 5,
#               'positive': 2}),
#  'состав': defaultdict(int, {'neutral': 3, 'positive': 4, 'negative': 3}),
#  'констатировать': defaultdict(int, {'negative': 4}),
#  'обстоятельство': defaultdict(int,
#              {'negative': 11, 'positive': 1, 'neutral': 1}),
#  'госпитализировать': defaultdict(int, {'negative': 7}),
#  'покушение': defaultdict(int, {'negative': 10, 'positive': 1}),
#  'автомобиль': defaultdict(int,
#              {'neutral': 1,
#               'negative': 1,
#               'positive': 2,
#               'positive/negative': 1}),
#  'Александр': defaultdict(int, {'positive': 2}),
#  'сесть': defaultdict(int, {'neutral': 1}),
#  'освещение': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'есть': defaultdict(int, {'neutral': 5, 'positive': 1, 'negative': 1}),
#  'переход': defaultdict(int, {'positive': 1}),
#  'Хенсен': defaultdict(int, {'positive': 1}),
#  'отрезать': defaultdict(int, {'negative': 1}),
#  'решение': defaultdict(int, {'positive': 23, 'neutral': 11, 'negative': 17}),
#  'подтверждать': defaultdict(int,
#              {'positive': 2, 'negative': 2, 'neutral': 1}),
#  'продолжаться': defaultdict(int,
#              {'positive': 1, 'negative': 6, 'positive/negative': 1}),
#  'действие': defaultdict(int,
#              {'positive': 9,
#               'negative': 16,
#               'positive/negative': 1,
#               'neutral': 1}),
#  'оправдать': defaultdict(int, {'positive': 2}),
#  'быть': defaultdict(int,
#              {'neutral': 8,
#               'positive': 13,
#               'negative': 37,
#               'positive/negative': 7}),
#  'сталкиваться': defaultdict(int, {'negative': 6, 'neutral': 3}),
#  'борьба': defaultdict(int,
#              {'positive/negative': 1,
#               'negative': 37,
#               'positive': 11,
#               'neutral': 4}),
#  'проявление': defaultdict(int, {'negative': 7, 'positive': 1}),
#  'виноватый': defaultdict(int, {'negative': 21}),
#  'одержать': defaultdict(int, {'positive': 22, 'positive/negative': 1}),
#  'записка': defaultdict(int, {'negative': 5, 'positive': 1}),
#  'знакомство': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'тянуться': defaultdict(int, {'negative': 1}),
#  'заразить': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'причастность': defaultdict(int,
#              {'negative': 8, 'neutral': 1, 'positive': 1}),
#  'заражение': defaultdict(int, {'negative': 6}),
#  'актер': defaultdict(int, {'positive': 3}),
#  'маска': defaultdict(int, {'neutral': 1, 'positive': 1}),
#  'тупой': defaultdict(int, {'neutral': 1}),
#  'разум': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'станция': defaultdict(int, {'positive': 1}),
#  'грозить': defaultdict(int, {'negative': 28, 'neutral': 4}),
#  'непосредственность': defaultdict(int, {'positive': 1}),
#  'исчезнуть': defaultdict(int, {'positive': 1}),
#  'простота': defaultdict(int, {'positive': 1}),
#  'свобода': defaultdict(int, {'positive': 4}),
#  'закон': defaultdict(int, {'positive': 5, 'negative': 11}),
#  'обладать': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'утверждение': defaultdict(int, {'negative': 2}),
#  'поляк': defaultdict(int, {'negative': 1}),
#  'память': defaultdict(int, {'neutral': 3, 'positive': 1, 'negative': 1}),
#  'лицо': defaultdict(int,
#              {'negative': 3,
#               'positive': 8,
#               'neutral': 2,
#               'positive/negative': 1}),
#  'получение': defaultdict(int,
#              {'positive/negative': 7, 'positive': 4, 'negative': 1}),
#  'начаться': defaultdict(int,
#              {'negative': 16,
#               'positive/negative': 1,
#               'neutral': 9,
#               'positive': 2}),
#  'ухудшение': defaultdict(int, {'positive/negative': 1, 'positive': 1}),
#  'больница': defaultdict(int, {'negative': 1}),
#  'кировлесаобвиняемый': defaultdict(int, {'positive/negative': 1}),
#  'режим': defaultdict(int, {'positive': 15, 'negative': 2, 'neutral': 4}),
#  'отправить': defaultdict(int,
#              {'negative': 16,
#               'neutral': 6,
#               'positive': 2,
#               'positive/negative': 1}),
#  'гимн': defaultdict(int, {'positive': 1}),
#  'заменить': defaultdict(int, {'positive': 1, 'neutral': 3, 'negative': 8}),
#  'сенатор': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'значение': defaultdict(int, {'neutral': 2, 'positive': 2}),
#  'атрибут': defaultdict(int, {'positive': 1}),
#  'дать': defaultdict(int, {'neutral': 6, 'positive': 7, 'negative': 9}),
#  'называть': defaultdict(int, {'negative': 16, 'positive': 9, 'neutral': 3}),
#  'пресечь': defaultdict(int, {'negative': 2}),
#  'переправить': defaultdict(int, {'neutral': 1}),
#  'документ': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'сделка': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'html': defaultdict(int, {'neutral': 1}),
#  'изумление': defaultdict(int, {'positive': 3}),
#  'моды00': defaultdict(int, {'positive': 1}),
#  'утопать': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'ликвидировать': defaultdict(int,
#              {'neutral': 1,
#               'negative': 3,
#               'positive': 2,
#               'positive/negative': 1}),
#  'формироваться': defaultdict(int, {'negative': 1}),
#  'усмотреть': defaultdict(int, {'negative': 2}),
#  'влияние': defaultdict(int, {'positive': 5, 'negative': 2, 'neutral': 1}),
#  'вернуть': defaultdict(int, {'positive': 20, 'negative': 5, 'neutral': 1}),
#  'следствие': defaultdict(int, {'negative': 1}),
#  'нести': defaultdict(int, {'negative': 7, 'positive': 7, 'neutral': 1}),
#  'теория': defaultdict(int, {'positive': 2}),
#  'период': defaultdict(int, {'neutral': 2, 'negative': 6, 'positive': 3}),
#  'темный': defaultdict(int, {'neutral': 1}),
#  'крыша': defaultdict(int, {'positive': 1}),
#  'с': defaultdict(int, {'positive': 82}),
#  'торчать': defaultdict(int, {'negative': 1}),
#  'утолить': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'ликвидация': defaultdict(int, {'negative': 2, 'neutral': 2, 'positive': 2}),
#  'разговор': defaultdict(int, {'positive': 5, 'negative': 2, 'neutral': 1}),
#  'необъективный': defaultdict(int, {'negative': 1}),
#  'призывать': defaultdict(int, {'positive': 2, 'neutral': 1, 'negative': 5}),
#  'помнить': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'устанавливать': defaultdict(int, {'positive': 4}),
#  'сотрудничать': defaultdict(int, {'negative': 4}),
#  'штраф': defaultdict(int, {'negative': 7, 'neutral': 1}),
#  'армия': defaultdict(int, {'negative': 6, 'positive': 7, 'neutral': 1}),
#  'УПА': defaultdict(int, {'negative': 3}),
#  'участник': defaultdict(int, {'negative': 3, 'positive': 4, 'neutral': 3}),
#  'организовывать': defaultdict(int,
#              {'positive': 5, 'negative': 5, 'neutral': 1}),
#  'Организация': defaultdict(int, {'negative': 3, 'positive': 2}),
#  'националист': defaultdict(int, {'negative': 1}),
#  'оценка': defaultdict(int, {'neutral': 5, 'negative': 2}),
#  'жертва': defaultdict(int,
#              {'negative': 15,
#               'neutral': 4,
#               'positive': 1,
#               'positive/negative': 1}),
#  'защитить': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'регулирование': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'стоить': defaultdict(int, {'negative': 7, 'positive': 8}),
#  'привязать': defaultdict(int, {'negative': 1}),
#  'прогноз': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'процент': defaultdict(int, {'positive': 6, 'neutral': 7, 'negative': 2}),
#  'лишиться': defaultdict(int,
#              {'positive/negative': 1, 'negative': 1, 'neutral': 1}),
#  'сеанс': defaultdict(int, {'positive': 1}),
#  'поесть': defaultdict(int, {'positive/negative': 1}),
#  'пытать': defaultdict(int, {'negative': 2}),
#  'убивать': defaultdict(int,
#              {'positive': 1, 'negative': 6, 'positive/negative': 4}),
#  'любовь': defaultdict(int, {'positive': 4, 'neutral': 1}),
#  'геймер': defaultdict(int, {'negative': 1}),
#  'неизвестный': defaultdict(int, {'positive': 1}),
#  'бороться': defaultdict(int, {'neutral': 3, 'negative': 12}),
#  'ввести': defaultdict(int,
#              {'negative': 9, 'neutral': 13, 'positive/negative': 7}),
#  'использование': defaultdict(int, {'negative': 4, 'positive': 1}),
#  'лечение': defaultdict(int, {'neutral': 3, 'negative': 8, 'positive': 1}),
#  'зависимость': defaultdict(int, {'negative': 2, 'neutral': 2}),
#  'работа': defaultdict(int, {'positive': 17, 'negative': 12, 'neutral': 2}),
#  'окончание': defaultdict(int, {'negative': 2}),
#  'договор': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'надеяться': defaultdict(int, {'negative': 2, 'positive': 6}),
#  'повышение': defaultdict(int, {'positive': 7, 'neutral': 1, 'negative': 1}),
#  'осведомленность': defaultdict(int, {'negative': 1}),
#  'оценивать': defaultdict(int, {'positive': 8, 'negative': 3, 'neutral': 1}),
#  'спасти': defaultdict(int,
#              {'positive': 2, 'negative': 1, 'positive/negative': 1}),
#  'спать': defaultdict(int, {'neutral': 1, 'positive': 2}),
#  'будить': defaultdict(int, {'neutral': 1}),
#  'доставить': defaultdict(int, {'negative': 3, 'positive': 2, 'neutral': 1}),
#  'поток': defaultdict(int, {'positive': 8}),
#  'выделить': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'прибыль': defaultdict(int, {'positive': 3}),
#  'сохранить': defaultdict(int, {'positive': 3, 'negative': 2}),
#  'сходить': defaultdict(int, {'negative': 2}),
#  'политика': defaultdict(int,
#              {'negative': 3,
#               'neutral': 3,
#               'positive': 3,
#               'positive/negative': 1}),
#  'говорить': defaultdict(int,
#              {'positive/negative': 1,
#               'negative': 16,
#               'positive': 9,
#               'neutral': 1}),
#  'очевидный': defaultdict(int, {'positive': 1}),
#  'нагрузка': defaultdict(int, {'negative': 2, 'positive': 14}),
#  'сокращать': defaultdict(int, {'neutral': 1, 'negative': 1, 'positive': 1}),
#  'попасть': defaultdict(int,
#              {'negative': 41,
#               'neutral': 7,
#               'positive/negative': 3,
#               'positive': 2}),
#  'Рейчел': defaultdict(int, {'negative': 1}),
#  'засыпать': defaultdict(int, {'positive/negative': 1}),
#  'яма': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'новость': defaultdict(int,
#              {'positive': 73,
#               'negative': 2,
#               'neutral': 8,
#               'positive/negative': 3}),
#  'чувство': defaultdict(int,
#              {'negative': 2,
#               'neutral': 2,
#               'positive': 3,
#               'positive/negative': 1}),
#  'отметить': defaultdict(int, {'negative': 13, 'neutral': 6, 'positive': 20}),
#  'сомневаться': defaultdict(int, {'positive': 2}),
#  'спортсмен': defaultdict(int, {'positive': 30, 'negative': 8}),
#  'оставлять': defaultdict(int, {'positive': 1}),
#  'поддержка': defaultdict(int, {'positive': 4, 'negative': 4, 'neutral': 2}),
#  'подвергнуться': defaultdict(int,
#              {'negative': 7, 'positive': 3, 'neutral': 4}),
#  'рэпер': defaultdict(int, {'positive': 2}),
#  'разорвать': defaultdict(int, {'negative': 2}),
#  'принимать': defaultdict(int, {'positive': 41, 'neutral': 4, 'negative': 3}),
#  'Шакур': defaultdict(int, {'positive': 1}),
#  'культ': defaultdict(int, {'positive': 2}),
#  'бог': defaultdict(int, {'negative': 3, 'positive': 2}),
#  'царица': defaultdict(int, {'positive': 2, 'neutral': 1}),
#  'славиться': defaultdict(int, {'positive': 2}),
#  'вырасти': defaultdict(int,
#              {'positive': 5, 'positive/negative': 1, 'neutral': 2}),
#  'найти': defaultdict(int, {'positive': 15, 'negative': 13, 'neutral': 1}),
#  'бренд': defaultdict(int, {'positive': 8}),
#  'разведка': defaultdict(int, {'neutral': 3, 'negative': 1}),
#  'трактовать': defaultdict(int, {'positive': 1}),
#  'требовать': defaultdict(int,
#              {'positive': 7,
#               'negative': 6,
#               'neutral': 1,
#               'positive/negative': 1}),
#  'скандал': defaultdict(int, {'positive/negative': 1, 'negative': 5}),
#  'вмешательство': defaultdict(int, {'negative': 3, 'neutral': 1}),
#  'убедиться': defaultdict(int, {'positive': 4}),
#  'преследование': defaultdict(int,
#              {'negative': 4, 'positive/negative': 2, 'neutral': 1}),
#  'наколкамиЗакон': defaultdict(int, {'positive': 1}),
#  'хороший': defaultdict(int,
#              {'negative': 1, 'positive': 2, 'positive/negative': 1}),
#  'проявиться': defaultdict(int, {'neutral': 1}),
#  'группа': defaultdict(int, {'negative': 14, 'neutral': 4, 'positive': 6}),
#  'повышать': defaultdict(int, {'negative': 7, 'positive': 3}),
#  'попадание': defaultdict(int, {'negative': 1}),
#  'Королевство': defaultdict(int, {'negative': 1}),
#  'существовать': defaultdict(int,
#              {'negative': 9,
#               'neutral': 1,
#               'positive/negative': 1,
#               'positive': 1}),
#  'стандартный': defaultdict(int, {'positive/negative': 1, 'positive': 2}),
#  'перехватить': defaultdict(int, {'negative': 1}),
#  'истребитель': defaultdict(int,
#              {'positive/negative': 1, 'neutral': 1, 'positive': 1}),
#  'перерастать': defaultdict(int,
#              {'positive/negative': 7, 'negative': 1, 'neutral': 3}),
#  'войнуОб': defaultdict(int, {'neutral': 1}),
#  'контакт': defaultdict(int,
#              {'positive': 3, 'positive/negative': 1, 'negative': 1}),
#  'обвинять': defaultdict(int, {'negative': 28, 'positive': 1, 'neutral': 1}),
#  'поддерживать': defaultdict(int,
#              {'negative': 1, 'neutral': 1, 'positive': 3}),
#  'наряду': defaultdict(int, {'positive': 1, 'positive/negative': 1}),
#  'демократия': defaultdict(int, {'positive': 2}),
#  'ничто': defaultdict(int, {'negative': 5, 'neutral': 3}),
#  'признание': defaultdict(int, {'positive': 3, 'negative': 1, 'neutral': 1}),
#  'предложить': defaultdict(int, {'neutral': 4, 'positive': 3, 'negative': 3}),
#  'обращать': defaultdict(int, {'positive': 5}),
#  'традиция': defaultdict(int, {'neutral': 1, 'negative': 1}),
#  'подвергать': defaultdict(int,
#              {'negative': 2, 'positive/negative': 2, 'positive': 1}),
#  'создать': defaultdict(int, {'neutral': 2, 'negative': 6, 'positive': 6}),
#  'предложение': defaultdict(int, {'positive': 4}),
#  'прогнозировать': defaultdict(int, {'positive': 2}),
#  'ждать': defaultdict(int,
#              {'positive': 7,
#               'neutral': 3,
#               'negative': 2,
#               'positive/negative': 2}),
#  'догнать': defaultdict(int, {'positive': 1}),
#  'удерживать': defaultdict(int, {'negative': 1}),
#  'литература': defaultdict(int, {'positive': 4, 'neutral': 2}),
#  'наталкиваться': defaultdict(int, {'negative': 1}),
#  '2017гомы': defaultdict(int, {'negative': 2}),
#  'книга': defaultdict(int, {'positive': 2, 'negative': 3}),
#  'слава': defaultdict(int, {'positive': 7}),
#  'служить': defaultdict(int, {'positive': 1, 'negative': 1, 'neutral': 1}),
#  'испытывать': defaultdict(int, {'negative': 6, 'positive': 2, 'neutral': 2}),
#  'требование': defaultdict(int, {'negative': 2, 'positive': 9}),
#  'руководитель': defaultdict(int,
#              {'positive': 5, 'negative': 1, 'neutral': 1}),
#  'поступка': defaultdict(int, {'negative': 1}),
#  'лежать': defaultdict(int, {'negative': 2, 'positive': 1, 'neutral': 2}),
#  'устроить': defaultdict(int, {'negative': 24, 'positive': 2}),
#  'тот': defaultdict(int, {'negative': 9, 'positive': 8}),
#  'школе00': defaultdict(int, {'positive': 2}),
#  'заслуживать': defaultdict(int, {'negative': 6, 'positive': 2}),
#  'желание': defaultdict(int,
#              {'negative': 8, 'positive': 1, 'positive/negative': 1}),
#  'выглядеть': defaultdict(int, {'negative': 2, 'positive': 9, 'neutral': 4}),
#  'семья': defaultdict(int, {'positive': 5, 'negative': 5, 'neutral': 2}),
#  'резня': defaultdict(int, {'negative': 2}),
#  'подозрение': defaultdict(int,
#              {'negative': 12,
#               'neutral': 1,
#               'positive': 3,
#               'positive/negative': 1}),
#  'энергия': defaultdict(int, {'neutral': 9, 'negative': 2, 'positive': 1}),
#  'материя': defaultdict(int, {'neutral': 9, 'positive': 1}),
#  'ВселеннаяМир': defaultdict(int, {'positive/negative': 1}),
#  'канал': defaultdict(int, {'negative': 4, 'positive': 2, 'neutral': 1}),
#  'подразумевать': defaultdict(int, {'negative': 2}),
#  'распадаться': defaultdict(int, {'positive': 1}),
#  'излучение': defaultdict(int,
#              {'neutral': 1,
#               'negative': 1,
#               'positive': 1,
#               'positive/negative': 1}),
#  'безмассовый': defaultdict(int, {'positive': 1}),
#  'позволять': defaultdict(int,
#              {'positive': 2,
#               'negative': 9,
#               'neutral': 1,
#               'positive/negative': 1}),
#  'происходить': defaultdict(int, {'negative': 5, 'positive/negative': 2}),
#  'параметр': defaultdict(int, {'neutral': 1}),
#  'галактика': defaultdict(int, {'neutral': 2}),
#  'вина': defaultdict(int, {'negative': 2}),
#  'житель': defaultdict(int, {'negative': 9, 'positive': 8, 'neutral': 1}),
#  'корзина': defaultdict(int, {'negative': 1}),
#  'распространять': defaultdict(int, {'negative': 6, 'neutral': 1}),
#  'приобретать': defaultdict(int, {'negative': 3, 'positive': 2}),
#  'Азияточема': defaultdict(int, {'neutral': 1}),
#  'эпоха': defaultdict(int, {'positive': 1}),
#  'прийтись': defaultdict(int,
#              {'positive': 3, 'negative': 8, 'positive/negative': 1}),
#  'занимать': defaultdict(int, {'positive': 3, 'neutral': 1, 'negative': 2}),
#  'смысл': defaultdict(int, {'positive': 2}),
#  'смерть': defaultdict(int, {'positive': 2, 'negative': 5}),
#  'литр': defaultdict(int, {'positive': 1}),
#  'газ': defaultdict(int, {'positive': 1}),
#  'отменить': defaultdict(int, {'negative': 10, 'positive': 2}),
#  'идти': defaultdict(int, {'positive': 9, 'negative': 8, 'neutral': 4}),
#  'оправдание': defaultdict(int, {'neutral': 1}),
#  'добиваться': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'конец': defaultdict(int, {'positive': 1}),
#  'что-то': defaultdict(int, {'negative': 13}),
#  'изучить': defaultdict(int, {'positive': 1}),
#  'оценить': defaultdict(int, {'positive': 6, 'negative': 1, 'neutral': 2}),
#  'отдых': defaultdict(int, {'positive': 2}),
#  'основать': defaultdict(int, {'positive': 1}),
#  'заключение': defaultdict(int, {'negative': 14, 'neutral': 1}),
#  'обрезание': defaultdict(int, {'negative': 1}),
#  'фактор': defaultdict(int,
#              {'positive': 12,
#               'neutral': 2,
#               'negative': 6,
#               'positive/negative': 2}),
#  'подход': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'характер': defaultdict(int,
#              {'positive/negative': 8, 'negative': 6, 'positive': 1}),
#  'поведение': defaultdict(int, {'negative': 10, 'neutral': 2, 'positive': 1}),
#  'госпожь': defaultdict(int, {'negative': 10}),
#  'знак': defaultdict(int, {'negative': 3, 'positive': 1}),
#  'насилие': defaultdict(int, {'positive/negative': 6, 'negative': 2}),
#  'харассмент': defaultdict(int, {'negative': 1, 'positive/negative': 1}),
#  'оправдаться': defaultdict(int, {'neutral': 1}),
#  'слово': defaultdict(int,
#              {'positive': 6,
#               'negative': 7,
#               'neutral': 1,
#               'positive/negative': 1}),
# ...
#               'positive': 3,
#               'neutral': 2,
#               'positive/negative': 1}),
#  'клуб': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'студент': defaultdict(int, {'negative': 4}),
#  'подтолкнуть': defaultdict(int, {'negative': 3, 'positive': 1}),
#  '***': defaultdict(int, {'negative': 1}),
#  'собрать': defaultdict(int, {'neutral': 2, 'negative': 2, 'positive': 3}),
#  'флешмоб': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'рассказывать': defaultdict(int,
#              {'negative': 9,
#               'positive/negative': 1,
#               'positive': 1,
#               'neutral': 2}),
#  'врач': defaultdict(int, {'negative': 4, 'positive': 1}),
#  'благодарить': defaultdict(int, {'positive': 4}),
#  'пересмотреть': defaultdict(int, {'negative': 1}),
#  'вывод': defaultdict(int, {'negative': 7, 'positive': 1}),
#  'противоречить': defaultdict(int, {'positive': 4, 'neutral': 2}),
#  'вред': defaultdict(int, {'positive': 5, 'negative': 3}),
#  'компенсация': defaultdict(int,
#              {'negative': 11, 'positive': 3, 'neutral': 1}),
#  'процедура': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'ряд': defaultdict(int, {'negative': 4, 'positive': 3}),
#  'болезнь': defaultdict(int, {'negative': 4}),
#  'миелофиброз': defaultdict(int, {'negative': 3}),
#  'онкология': defaultdict(int, {'negative': 3}),
#  'относиться': defaultdict(int, {'positive': 4, 'negative': 4, 'neutral': 1}),
#  'точный': defaultdict(int, {'neutral': 1}),
#  'точка': defaultdict(int, {'positive': 4, 'negative': 1, 'neutral': 1}),
#  'заниматься': defaultdict(int, {'negative': 14, 'positive': 2, 'neutral': 2}),
#  'забраться': defaultdict(int, {'negative': 1}),
#  'зоопаркСпасатель': defaultdict(int, {'positive': 1}),
#  'потрудиться': defaultdict(int, {'negative': 1}),
#  'спасать': defaultdict(int, {'neutral': 1, 'negative': 1}),
#  'игра': defaultdict(int, {'positive': 8, 'negative': 2}),
#  'посетить': defaultdict(int, {'positive': 1}),
#  'свежий': defaultdict(int, {'positive': 1}),
#  'ремонт': defaultdict(int, {'positive': 7}),
#  'реконструкция': defaultdict(int, {'positive': 1}),
#  'средства': defaultdict(int,
#              {'positive': 10,
#               'negative': 6,
#               'positive/negative': 3,
#               'neutral': 1}),
#  'утверждать': defaultdict(int,
#              {'positive': 5,
#               'negative': 7,
#               'neutral': 2,
#               'positive/negative': 2}),
#  'россиянин': defaultdict(int, {'positive': 7, 'negative': 4}),
#  'продюсер': defaultdict(int, {'positive': 3, 'neutral': 1}),
#  'расположить': defaultdict(int, {'positive': 1}),
#  'журнал': defaultdict(int, {'positive': 1}),
#  'искренний': defaultdict(int, {'positive/negative': 1, 'positive': 1}),
#  'разговаривать': defaultdict(int, {'negative': 1}),
#  'удивляться': defaultdict(int, {'negative': 1}),
#  'падение': defaultdict(int, {'positive': 1, 'neutral': 1, 'negative': 2}),
#  'Запад': defaultdict(int, {'positive': 1, 'neutral': 1}),
#  'рассуждать': defaultdict(int, {'negative': 1}),
#  'риск': defaultdict(int,
#              {'negative': 13,
#               'neutral': 5,
#               'positive': 1,
#               'positive/negative': 1}),
#  'растерять': defaultdict(int, {'positive': 1}),
#  'корень': defaultdict(int, {'positive': 2}),
#  'осуществление': defaultdict(int, {'neutral': 1}),
#  'связывать': defaultdict(int, {'positive': 4, 'negative': 1, 'neutral': 2}),
#  'превратиться': defaultdict(int, {'negative': 2}),
#  'надежда': defaultdict(int, {'positive': 4}),
#  'исполнение': defaultdict(int, {'negative': 3, 'neutral': 1}),
#  'ук': defaultdict(int, {'negative': 4}),
#  'статья': defaultdict(int, {'negative': 20, 'positive': 2, 'neutral': 1}),
#  'производство': defaultdict(int,
#              {'positive': 3, 'negative': 4, 'neutral': 2}),
#  'строительство': defaultdict(int,
#              {'negative': 1, 'neutral': 2, 'positive': 1}),
#  'тюрьма': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'тишинуОхранник': defaultdict(int, {'negative': 2}),
#  'арестант': defaultdict(int, {'positive': 2}),
#  'отбывать': defaultdict(int, {'negative': 11}),
#  'руководить': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'соучастник': defaultdict(int, {'negative': 1}),
#  'обувь': defaultdict(int, {'negative': 3}),
#  'нанести': defaultdict(int, {'negative': 58}),
#  'цена': defaultdict(int, {'negative': 7, 'neutral': 4, 'positive': 2}),
#  'Радио': defaultdict(int, {'positive': 1}),
#  'ухищрение': defaultdict(int, {'neutral': 1}),
#  'удаться': defaultdict(int, {'positive': 8, 'neutral': 3}),
#  'калибр': defaultdict(int, {'neutral': 1}),
#  'девочка': defaultdict(int, {'positive': 3, 'negative': 4}),
#  'имплант': defaultdict(int, {'positive': 1}),
#  'маленький': defaultdict(int, {'neutral': 1, 'positive': 1}),
#  'аниме-девочка': defaultdict(int, {'neutral': 1}),
#  'повторять': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'продолжить': defaultdict(int, {'negative': 9, 'positive': 2}),
#  'попытка': defaultdict(int,
#              {'negative': 15,
#               'positive/negative': 1,
#               'positive': 1,
#               'neutral': 3}),
#  'фальсифицировать': defaultdict(int, {'positive': 1}),
#  'обелять': defaultdict(int, {'negative': 1}),
#  'воин': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'вирус': defaultdict(int, {'negative': 6, 'neutral': 1}),
#  'иммунитет': defaultdict(int, {'negative': 1}),
#  'беспокойство': defaultdict(int, {'positive': 2}),
#  'расправить': defaultdict(int, {'negative': 1}),
#  'неонацист': defaultdict(int, {'neutral': 1}),
#  '75-летие': defaultdict(int, {'positive': 1}),
#  'линия': defaultdict(int, {'negative': 1, 'neutral': 1, 'positive': 4}),
#  'положить': defaultdict(int, {'positive': 1}),
#  'война': defaultdict(int, {'positive': 12, 'negative': 5, 'neutral': 2}),
#  'перелом': defaultdict(int, {'negative': 1, 'positive': 2}),
#  'день': defaultdict(int, {'negative': 10, 'neutral': 2, 'positive': 5}),
#  'войска': defaultdict(int, {'negative': 3, 'positive': 2}),
#  'сражение': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'череда': defaultdict(int, {'positive/negative': 1, 'neutral': 1}),
#  'переломный': defaultdict(int, {'negative': 1}),
#  'телепрограмма': defaultdict(int, {'negative': 1}),
#  'эфир': defaultdict(int, {'positive': 9, 'negative': 1}),
#  'хирург': defaultdict(int, {'neutral': 1}),
#  'стоимость': defaultdict(int, {'neutral': 4, 'positive': 4}),
#  'центр': defaultdict(int, {'positive': 4, 'negative': 7}),
#  'освобождение': defaultdict(int, {'negative': 3}),
#  'динамика': defaultdict(int, {'positive': 5}),
#  'суд': defaultdict(int,
#              {'positive': 3, 'negative': 2, 'positive/negative': 1}),
#  'восторжествовать': defaultdict(int, {'positive': 1}),
#  'иностранец': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'поляхКто': defaultdict(int, {'positive': 1}),
#  'узза': defaultdict(int, {'positive': 1}),
#  'линейка': defaultdict(int, {'neutral': 1, 'negative': 1}),
#  'перелезти': defaultdict(int, {'positive': 1}),
#  'произведение': defaultdict(int, {'positive': 3}),
#  'художник': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'прозвать': defaultdict(int, {'neutral': 1, 'positive/negative': 1}),
#  'отрицать': defaultdict(int, {'negative': 3, 'neutral': 4}),
#  'узнавать': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'Толстой': defaultdict(int, {'negative': 1}),
#  'осудить': defaultdict(int, {'negative': 10, 'neutral': 1, 'positive': 1}),
#  'колледж': defaultdict(int, {'positive': 1}),
#  'смущать': defaultdict(int, {'positive': 1}),
#  'вод': defaultdict(int, {'negative': 1}),
#  'разработать': defaultdict(int, {'positive': 1, 'negative': 2}),
#  'пистолет': defaultdict(int, {'neutral': 3}),
#  'детектив': defaultdict(int, {'positive': 1}),
#  'ограбление': defaultdict(int, {'negative': 2}),
#  'вторжение': defaultdict(int, {'negative': 1}),
#  'наркотик': defaultdict(int, {'negative': 1, 'positive': 2}),
#  'взрыв': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'раздаться': defaultdict(int, {'positive/negative': 1}),
#  'здание': defaultdict(int, {'neutral': 1, 'negative': 1, 'positive': 1}),
#  'строение': defaultdict(int, {'positive/negative': 1}),
#  'запчасть': defaultdict(int, {'positive/negative': 1}),
#  'освещать': defaultdict(int, {'negative': 3}),
#  'обстрелять': defaultdict(int,
#              {'negative': 1, 'positive': 1, 'positive/negative': 1}),
#  'уточнять': defaultdict(int, {'negative': 2, 'positive': 1}),
#  'засекретить': defaultdict(int, {'negative': 1}),
#  'означать': defaultdict(int,
#              {'negative': 4, 'positive': 2, 'positive/negative': 1}),
#  'расширение': defaultdict(int, {'positive/negative': 2, 'positive': 2}),
#  'крик': defaultdict(int, {'positive': 1}),
#  'половина': defaultdict(int, {'positive': 3, 'neutral': 1}),
#  'школьница': defaultdict(int, {'negative': 1}),
#  'жаловаться': defaultdict(int, {'negative': 7, 'positive': 1}),
#  'внедорожник': defaultdict(int, {'positive': 2}),
#  'безработный': defaultdict(int, {'positive': 1}),
#  'изъять': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'орудие': defaultdict(int, {'negative': 3, 'positive': 2}),
#  'микротия': defaultdict(int, {'negative': 1}),
#  'ухо': defaultdict(int, {'neutral': 1, 'positive': 2}),
#  'раковина': defaultdict(int, {'negative': 1, 'positive': 1}),
#  'внедряться': defaultdict(int, {'negative': 1}),
#  'эффективный': defaultdict(int, {'negative': 2}),
#  'пририсовать': defaultdict(int, {'positive': 2}),
#  'нормальный': defaultdict(int, {'positive': 1}),
#  'мысль': defaultdict(int, {'negative': 3}),
#  'программа': defaultdict(int, {'positive': 8, 'negative': 7, 'neutral': 1}),
#  'вопрос': defaultdict(int,
#              {'positive': 14,
#               'negative': 7,
#               'neutral': 2,
#               'positive/negative': 3}),
#  'блок': defaultdict(int,
#              {'positive': 1, 'positive/negative': 1, 'negative': 1}),
#  'круг': defaultdict(int, {'positive': 4, 'negative': 2}),
#  'сессия': defaultdict(int, {'positive': 1}),
#  'посвятить': defaultdict(int, {'positive': 6, 'negative': 3, 'neutral': 1}),
#  'деньги': defaultdict(int,
#              {'negative': 3, 'positive': 2, 'positive/negative': 1}),
#  'формирование': defaultdict(int,
#              {'negative': 7, 'neutral': 1, 'positive': 1}),
#  'врезка': defaultdict(int, {'negative': 1}),
#  'сообщать': defaultdict(int,
#              {'negative': 41,
#               'positive': 11,
#               'neutral': 6,
#               'positive/negative': 3}),
#  'назначить': defaultdict(int, {'negative': 8, 'positive': 1}),
#  'слушать': defaultdict(int, {'negative': 1}),
#  'самочувствие': defaultdict(int, {'negative': 2}),
#  'вымогательство': defaultdict(int, {'positive/negative': 1, 'negative': 1}),
#  'направить': defaultdict(int, {'positive': 5, 'negative': 5, 'neutral': 3}),
#  'цель': defaultdict(int, {'negative': 6, 'positive': 6, 'neutral': 2}),
#  'задержание': defaultdict(int, {'negative': 4}),
#  'возмещать': defaultdict(int, {'negative': 1}),
#  'терять': defaultdict(int,
#              {'positive': 6, 'positive/negative': 3, 'negative': 5}),
#  'мешать': defaultdict(int, {'positive': 1}),
#  'основание': defaultdict(int, {'positive': 10, 'negative': 2, 'neutral': 3}),
#  'отмена': defaultdict(int, {'negative': 7, 'neutral': 1, 'positive': 1}),
#  'дисквалификация': defaultdict(int, {'negative': 1}),
#  'спорт': defaultdict(int, {'positive': 5}),
#  'все': defaultdict(int, {'positive': 3, 'negative': 1, 'neutral': 2}),
#  'целостность': defaultdict(int, {'neutral': 1, 'negative': 1}),
#  'покрыть': defaultdict(int, {'negative': 3, 'neutral': 2}),
#  'забота': defaultdict(int, {'positive': 2, 'negative': 1}),
#  'предшественник': defaultdict(int, {'positive': 1}),
#  'оставаться': defaultdict(int,
#              {'neutral': 2,
#               'negative': 9,
#               'positive': 2,
#               'positive/negative': 1}),
#  'угроза': defaultdict(int, {'positive': 12, 'negative': 8, 'neutral': 2}),
#  'ставить': defaultdict(int, {'negative': 7, 'positive': 2, 'neutral': 2}),
#  'возможность': defaultdict(int,
#              {'positive': 4,
#               'neutral': 1,
#               'negative': 7,
#               'positive/negative': 1}),
#  'обстановка': defaultdict(int, {'positive': 3, 'negative': 1}),
#  'взвешивать': defaultdict(int, {'negative': 1}),
#  'спецслужба': defaultdict(int, {'negative': 1}),
#  'летчик': defaultdict(int, {'negative': 7, 'neutral': 1, 'positive': 17}),
#  'метод': defaultdict(int, {'neutral': 1, 'negative': 4, 'positive': 1}),
#  'склонить': defaultdict(int, {'negative': 1}),
#  'надуманность': defaultdict(int, {'neutral': 1}),
#  'срок': defaultdict(int, {'neutral': 8, 'negative': 10, 'positive': 5}),
#  'наличие': defaultdict(int, {'positive/negative': 2, 'negative': 3}),
#  'композиция': defaultdict(int, {'positive': 3}),
#  'базироваться': defaultdict(int, {'positive': 1}),
#  'аромат': defaultdict(int, {'positive': 2}),
#  'соблазнять': defaultdict(int, {'positive': 1}),
#  'заключить': defaultdict(int, {'positive': 3, 'negative': 1}),
#  'стекло': defaultdict(int, {'neutral': 1}),
#  'дозаправка': defaultdict(int, {'positive': 1}),
#  'направление': defaultdict(int,
#              {'positive': 4, 'neutral': 2, 'positive/negative': 1}),
#  'открыть': defaultdict(int, {'positive': 5, 'positive/negative': 1}),
#  'включая': defaultdict(int, {'positive': 2, 'negative': 1, 'neutral': 1}),
#  'субсидирование': defaultdict(int, {'positive': 1}),
#  'расход': defaultdict(int, {'positive': 1, 'negative': 1, 'neutral': 2}),
#  'gif-сервис': defaultdict(int, {'positive': 1}),
#  'инструмент': defaultdict(int,
#              {'positive': 9, 'positive/negative': 1, 'negative': 2}),
#  'генерирование': defaultdict(int, {'positive': 1}),
#  'обратиться': defaultdict(int,
#              {'negative': 3, 'positive': 5, 'positive/negative': 1}),
#  'последующий': defaultdict(int, {'negative': 1}),
#  'предрекнуть': defaultdict(int, {'neutral': 1}),
#  'провоцировать': defaultdict(int, {'neutral': 4, 'negative': 1}),
#  'ослабление': defaultdict(int, {'positive/negative': 1}),
#  'организм': defaultdict(int, {'positive': 3}),
#  'внести': defaultdict(int, {'negative': 1, 'positive': 6}),
#  'нет': defaultdict(int,
#              {'negative': 10,
#               'positive': 5,
#               'neutral': 5,
#               'positive/negative': 2}),
#  'бизнесмен': defaultdict(int, {'positive': 4}),
#  'благо': defaultdict(int, {'positive': 1}),
#  'честь': defaultdict(int, {'positive': 10, 'negative': 1, 'neutral': 1}),
#  'уважение': defaultdict(int, {'negative': 2, 'positive': 2}),
#  'верить': defaultdict(int, {'positive': 7}),
#  'нация': defaultdict(int, {'positive/negative': 1}),
#  'уничтожать': defaultdict(int, {'positive': 1}),
#  'медаль': defaultdict(int, {'positive': 1}),
#  'плакать': defaultdict(int, {'positive': 1, 'negative': 1}),
#  'подозревать': defaultdict(int,
#              {'negative': 8,
#               'positive': 3,
#               'neutral': 2,
#               'positive/negative': 1}),
#  'пособничество': defaultdict(int, {'negative': 4}),
#  'погибать': defaultdict(int, {'negative': 11}),
#  'перевод': defaultdict(int, {'positive': 2}),
#  'введение': defaultdict(int,
#              {'positive/negative': 10, 'negative': 5, 'positive': 1}),
#  'подпадать': defaultdict(int, {'positive/negative': 1, 'negative': 1}),
#  'заставить': defaultdict(int,
#              {'positive/negative': 1, 'positive': 3, 'negative': 5}),
#  'подрыть': defaultdict(int, {'positive': 2, 'negative': 2}),
#  'усилие': defaultdict(int, {'positive': 2}),
#  'ослабить': defaultdict(int, {'positive': 1}),
#  'орган': defaultdict(int, {'positive': 5, 'neutral': 1}),
#  'предоставить': defaultdict(int,
#              {'negative': 1, 'positive': 1, 'neutral': 1}),
#  'ездить': defaultdict(int, {'positive/negative': 1}),
#  'быстрый': defaultdict(int, {'positive': 1}),
#  'потерять': defaultdict(int, {'negative': 1}),
#  'развивать': defaultdict(int,
#              {'positive/negative': 1, 'positive': 4, 'neutral': 1}),
#  'ситуация': defaultdict(int, {'positive': 4, 'negative': 15, 'neutral': 7}),
#  'возмутить': defaultdict(int, {'positive': 2}),
#  'соответствовать': defaultdict(int,
#              {'positive': 6, 'neutral': 2, 'negative': 1}),
#  'исследование': defaultdict(int,
#              {'positive': 1, 'negative': 2, 'neutral': 1}),
#  ...}

# %%
[(senti, vals) for senti,vals in sentiments.items() if vals['negative']>10], '\n----\n',\
[(senti, vals) for senti,vals in sentiments.items() if vals['positive']>10]
# Out:
# ([('являться',
#    defaultdict(int,
#                {'neutral': 8,
#                 'positive': 18,
#                 'negative': 24,
#                 'positive/negative': 2})),
#   ('выразить',
#    defaultdict(int, {'positive': 13, 'negative': 29, 'neutral': 1})),
#   (None,
#    defaultdict(int,
#                {'positive': 689,
#                 'negative': 757,
#                 'neutral': 117,
#                 'positive/negative': 86})),
#   ('результат',
#    defaultdict(int,
#                {'negative': 29,
#                 'neutral': 9,
#                 'positive': 21,
#                 'positive/negative': 3})),
#   ('получить',
#    defaultdict(int,
#                {'negative': 60,
#                 'positive': 31,
#                 'neutral': 6,
#                 'positive/negative': 4})),
#   ('страдать',
#    defaultdict(int,
#                {'negative': 30,
#                 'neutral': 4,
#                 'positive/negative': 2,
#                 'positive': 0})),
#   ('один', defaultdict(int, {'neutral': 6, 'negative': 24, 'positive': 27})),
#   ('стать',
#    defaultdict(int,
#                {'negative': 89,
#                 'positive': 55,
#                 'neutral': 34,
#                 'positive/negative': 7})),
#   ('признать',
#    defaultdict(int, {'negative': 69, 'positive': 16, 'neutral': 3})),
#   ('материал',
#    defaultdict(int, {'negative': 37, 'positive': 8, 'neutral': 6})),
#   ('вызывать',
#    defaultdict(int, {'negative': 26, 'positive': 5, 'neutral': 1})),
#   ('находиться',
#    defaultdict(int,
#                {'negative': 41,
#                 'positive': 7,
#                 'positive/negative': 3,
#                 'neutral': 4})),
#   ('обвинить',
#    defaultdict(int, {'negative': 41, 'positive': 3, 'neutral': 1})),
#   ('сообщить',
#    defaultdict(int,
#                {'пострадать': 1,
#                 'negative': 23,
#                 'positive': 16,
#                 'neutral': 5,
#                 'positive/negative': 3})),
#   ('обнаружить',
#    defaultdict(int,
#                {'пострадать': 1,
#                 'negative': 18,
#                 'positive': 6,
#                 'neutral': 4})),
#   ('арестовывать',
#    defaultdict(int, {'neutral': 4, 'negative': 12, 'positive': 1})),
#   ('обвинение',
#    defaultdict(int,
#                {'negative': 29,
#                 'positive': 3,
#                 'neutral': 2,
#                 'positive/negative': 1})),
#   ('обращение', defaultdict(int, {'positive': 2, 'negative': 11})),
#   ('ребенок', defaultdict(int, {'positive': 2, 'negative': 12, 'neutral': 4})),
#   ('должен',
#    defaultdict(int,
#                {'positive': 28,
#                 'neutral': 5,
#                 'negative': 14,
#                 'positive/negative': 2})),
#   ('серия',
#    defaultdict(int,
#                {'positive': 2,
#                 'negative': 12,
#                 'neutral': 5,
#                 'positive/negative': 2})),
#   ('история', defaultdict(int, {'negative': 14, 'positive': 8})),
#   ('мочь',
#    defaultdict(int,
#                {'negative': 81,
#                 'positive': 55,
#                 'positive/negative': 8,
#                 'neutral': 19})),
#   ('ответственность',
#    defaultdict(int,
#                {'negative': 21,
#                 'positive/negative': 1,
#                 'positive': 9,
#                 'neutral': 1})),
#   ('дело', defaultdict(int, {'negative': 156, 'neutral': 1, 'positive': 6})),
#   ('задержать',
#    defaultdict(int, {'negative': 26, 'neutral': 4, 'positive': 0})),
#   ('совершение',
#    defaultdict(int,
#                {'negative': 13,
#                 'positive/negative': 1,
#                 'neutral': 2,
#                 'positive': 0})),
#   ('акция', defaultdict(int, {'negative': 12, 'positive': 1, 'neutral': 1})),
#   ('заявить',
#    defaultdict(int,
#                {'negative': 35,
#                 'positive': 28,
#                 'neutral': 10,
#                 'positive/negative': 1})),
#   ('расследование',
#    defaultdict(int, {'negative': 18, 'positive/negative': 1, 'positive': 0})),
#   ('оказаться',
#    defaultdict(int,
#                {'neutral': 7,
#                 'negative': 25,
#                 'positive': 28,
#                 'positive/negative': 3})),
#   ('считать',
#    defaultdict(int,
#                {'negative': 39,
#                 'positive': 16,
#                 'neutral': 3,
#                 'positive/negative': 4})),
#   ('потерпеть',
#    defaultdict(int, {'negative': 22, 'positive/negative': 7, 'positive': 2})),
#   ('видео',
#    defaultdict(int,
#                {'positive': 13,
#                 'negative': 23,
#                 'positive/negative': 2,
#                 'neutral': 1})),
#   ('признавать',
#    defaultdict(int, {'positive': 6, 'neutral': 2, 'negative': 14})),
#   ('назвать',
#    defaultdict(int,
#                {'positive': 30,
#                 'negative': 40,
#                 'positive/negative': 5,
#                 'neutral': 8})),
#   ('вызвать',
#    defaultdict(int,
#                {'neutral': 9,
#                 'negative': 28,
#                 'positive/negative': 2,
#                 'positive': 6})),
#   ('подать', defaultdict(int, {'negative': 24, 'positive': 2, 'neutral': 2})),
#   ('проблема',
#    defaultdict(int,
#                {'positive/negative': 1,
#                 'negative': 11,
#                 'positive': 9,
#                 'neutral': 1})),
#   ('связать',
#    defaultdict(int,
#                {'neutral': 2,
#                 'negative': 20,
#                 'positive': 8,
#                 'positive/negative': 2})),
#   ('причина',
#    defaultdict(int,
#                {'neutral': 6,
#                 'negative': 47,
#                 'positive/negative': 3,
#                 'positive': 5})),
#   ('наносить', defaultdict(int, {'negative': 15, 'positive': 0})),
#   ('контент',
#    defaultdict(int, {'negative': 12, 'positive/negative': 1, 'positive': 0})),
#   ('ролик', defaultdict(int, {'positive': 11, 'negative': 11, 'neutral': 3})),
#   ('делать',
#    defaultdict(int,
#                {'negative': 22,
#                 'positive': 21,
#                 'positive/negative': 3,
#                 'neutral': 12})),
#   ('привести',
#    defaultdict(int,
#                {'negative': 32,
#                 'positive': 10,
#                 'neutral': 1,
#                 'positive/negative': 2})),
#   ('случай',
#    defaultdict(int,
#                {'positive/negative': 1,
#                 'negative': 35,
#                 'positive': 6,
#                 'neutral': 3})),
#   ('факт', defaultdict(int, {'negative': 20, 'positive': 4, 'neutral': 3})),
#   ('видеть', defaultdict(int, {'negative': 13, 'positive': 9, 'neutral': 7})),
#   ('преступление',
#    defaultdict(int, {'neutral': 1, 'negative': 16, 'positive': 1})),
#   ('деятельность',
#    defaultdict(int, {'negative': 38, 'positive': 6, 'neutral': 1})),
#   ('место',
#    defaultdict(int,
#                {'positive': 10,
#                 'neutral': 6,
#                 'negative': 34,
#                 'positive/negative': 14})),
#   ('счесть', defaultdict(int, {'positive': 5, 'negative': 14, 'neutral': 2})),
#   ('то',
#    defaultdict(int,
#                {'negative': 36,
#                 'positive': 29,
#                 'positive/negative': 2,
#                 'neutral': 5})),
#   ('рассказать',
#    defaultdict(int,
#                {'negative': 36,
#                 'neutral': 5,
#                 'positive': 17,
#                 'positive/negative': 5})),
#   ('человек',
#    defaultdict(int, {'positive': 28, 'neutral': 5, 'negative': 21})),
#   ('фильм',
#    defaultdict(int, {'negative': 18, 'positive': 9, 'positive/negative': 2})),
#   ('ИГ', defaultdict(int, {'negative': 32, 'positive': 0})),
#   ('организация', defaultdict(int, {'negative': 29, 'positive': 18})),
#   ('совершить',
#    defaultdict(int, {'negative': 23, 'neutral': 2, 'positive': 2})),
#   ('состояние',
#    defaultdict(int,
#                {'negative': 15,
#                 'positive/negative': 8,
#                 'positive': 5,
#                 'neutral': 2})),
#   ('участие', defaultdict(int, {'negative': 24, 'positive': 9, 'neutral': 4})),
#   ('виновный',
#    defaultdict(int, {'negative': 18, 'neutral': 1, 'positive': 0})),
#   ('погибнуть',
#    defaultdict(int,
#                {'negative': 30,
#                 'positive': 4,
#                 'positive/negative': 1,
#                 'neutral': 7})),
#   ('причинение', defaultdict(int, {'negative': 17, 'positive': 0})),
#   ('родственник', defaultdict(int, {'negative': 11, 'positive': 4})),
#   ('год',
#    defaultdict(int,
#                {'neutral': 17,
#                 'negative': 47,
#                 'positive/negative': 2,
#                 'positive': 2})),
#   ('территория', defaultdict(int, {'negative': 14, 'positive': 0})),
#   ('снять',
#    defaultdict(int,
#                {'negative': 13,
#                 'neutral': 10,
#                 'positive': 3,
#                 'positive/negative': 3})),
#   ('произойти',
#    defaultdict(int,
#                {'negative': 88,
#                 'neutral': 9,
#                 'positive/negative': 5,
#                 'positive': 2})),
#   ('обстоятельство',
#    defaultdict(int, {'negative': 11, 'positive': 1, 'neutral': 1})),
#   ('решение',
#    defaultdict(int, {'positive': 23, 'neutral': 11, 'negative': 17})),
#   ('действие',
#    defaultdict(int,
#                {'positive': 9,
#                 'negative': 16,
#                 'positive/negative': 1,
#                 'neutral': 1})),
#   ('быть',
#    defaultdict(int,
#                {'neutral': 8,
#                 'positive': 13,
#                 'negative': 37,
#                 'positive/negative': 7})),
#   ('борьба',
#    defaultdict(int,
#                {'positive/negative': 1,
#                 'negative': 37,
#                 'positive': 11,
#                 'neutral': 4})),
#   ('виноватый', defaultdict(int, {'negative': 21, 'positive': 0})),
#   ('грозить', defaultdict(int, {'negative': 28, 'neutral': 4, 'positive': 0})),
#   ('закон', defaultdict(int, {'positive': 5, 'negative': 11})),
#   ('начаться',
#    defaultdict(int,
#                {'negative': 16,
#                 'positive/negative': 1,
#                 'neutral': 9,
#                 'positive': 2})),
#   ('отправить',
#    defaultdict(int,
#                {'negative': 16,
#                 'neutral': 6,
#                 'positive': 2,
#                 'positive/negative': 1})),
#   ('называть',
#    defaultdict(int, {'negative': 16, 'positive': 9, 'neutral': 3})),
#   ('жертва',
#    defaultdict(int,
#                {'negative': 15,
#                 'neutral': 4,
#                 'positive': 1,
#                 'positive/negative': 1})),
#   ('бороться',
#    defaultdict(int, {'neutral': 3, 'negative': 12, 'positive': 0})),
#   ('работа', defaultdict(int, {'positive': 17, 'negative': 12, 'neutral': 2})),
#   ('говорить',
#    defaultdict(int,
#                {'positive/negative': 1,
#                 'negative': 16,
#                 'positive': 9,
#                 'neutral': 1})),
#   ('попасть',
#    defaultdict(int,
#                {'negative': 41,
#                 'neutral': 7,
#                 'positive/negative': 3,
#                 'positive': 2})),
#   ('отметить',
#    defaultdict(int, {'negative': 13, 'neutral': 6, 'positive': 20})),
#   ('найти', defaultdict(int, {'positive': 15, 'negative': 13, 'neutral': 1})),
#   ('группа', defaultdict(int, {'negative': 14, 'neutral': 4, 'positive': 6})),
#   ('обвинять',
#    defaultdict(int, {'negative': 28, 'positive': 1, 'neutral': 1})),
#   ('устроить', defaultdict(int, {'negative': 24, 'positive': 2})),
#   ('подозрение',
#    defaultdict(int,
#                {'negative': 12,
#                 'neutral': 1,
#                 'positive': 3,
#                 'positive/negative': 1})),
#   ('что-то', defaultdict(int, {'negative': 13, 'positive': 0})),
#   ('заключение',
#    defaultdict(int, {'negative': 14, 'neutral': 1, 'positive': 0})),
#   ('группировка',
#    defaultdict(int, {'negative': 58, 'neutral': 4, 'positive': 0})),
#   ('хотеть',
#    defaultdict(int,
#                {'negative': 18,
#                 'positive': 7,
#                 'positive/negative': 1,
#                 'neutral': 1})),
#   ('решить', defaultdict(int, {'neutral': 7, 'positive': 13, 'negative': 12})),
#   ('женщина',
#    defaultdict(int, {'positive': 11, 'negative': 11, 'neutral': 1})),
#   ('приговорить',
#    defaultdict(int, {'neutral': 6, 'positive': 2, 'negative': 13})),
#   ('вещество',
#    defaultdict(int, {'negative': 12, 'neutral': 2, 'positive': 0})),
#   ('добавить',
#    defaultdict(int, {'positive': 14, 'negative': 11, 'neutral': 1})),
#   ('компенсация',
#    defaultdict(int, {'negative': 11, 'positive': 3, 'neutral': 1})),
#   ('заниматься',
#    defaultdict(int, {'negative': 14, 'positive': 2, 'neutral': 2})),
#   ('риск',
#    defaultdict(int,
#                {'negative': 13,
#                 'neutral': 5,
#                 'positive': 1,
#                 'positive/negative': 1})),
#   ('статья', defaultdict(int, {'negative': 20, 'positive': 2, 'neutral': 1})),
#   ('отбывать', defaultdict(int, {'negative': 11, 'positive': 0})),
#   ('нанести', defaultdict(int, {'negative': 58, 'positive': 0})),
#   ('попытка',
#    defaultdict(int,
#                {'negative': 15,
#                 'positive/negative': 1,
#                 'positive': 1,
#                 'neutral': 3})),
#   ('сообщать',
#    defaultdict(int,
#                {'negative': 41,
#                 'positive': 11,
#                 'neutral': 6,
#                 'positive/negative': 3})),
#   ('погибать', defaultdict(int, {'negative': 11, 'positive': 0})),
#   ('ситуация',
#    defaultdict(int, {'positive': 4, 'negative': 15, 'neutral': 7})),
#   ('момент',
#    defaultdict(int,
#                {'negative': 14,
#                 'neutral': 6,
#                 'positive': 9,
#                 'positive/negative': 5})),
#   ('информация',
#    defaultdict(int, {'positive': 8, 'neutral': 2, 'negative': 17})),
#   ('отмечать',
#    defaultdict(int,
#                {'neutral': 3,
#                 'positive': 12,
#                 'negative': 11,
#                 'positive/negative': 1})),
#   ('начать',
#    defaultdict(int,
#                {'positive/negative': 1,
#                 'neutral': 3,
#                 'negative': 14,
#                 'positive': 3})),
#   ('вести',
#    defaultdict(int,
#                {'positive/negative': 1,
#                 'positive': 4,
#                 'negative': 13,
#                 'neutral': 4})),
#   ('операция',
#    defaultdict(int, {'negative': 14, 'neutral': 2, 'positive': 5})),
#   ('сообщение',
#    defaultdict(int, {'negative': 13, 'positive': 3, 'neutral': 1})),
#   ('пытаться',
#    defaultdict(int, {'negative': 20, 'positive': 9, 'neutral': 2})),
#   ('избегнуть',
#    defaultdict(int,
#                {'negative': 33,
#                 'positive/negative': 1,
#                 'neutral': 2,
#                 'positive': 0})),
#   ('препарат', defaultdict(int, {'negative': 18, 'positive': 1})),
#   ('объявить',
#    defaultdict(int,
#                {'neutral': 6,
#                 'positive': 4,
#                 'negative': 12,
#                 'positive/negative': 1})),
#   ('допустить', defaultdict(int, {'negative': 12, 'positive': 7})),
#   ('составить',
#    defaultdict(int, {'neutral': 4, 'negative': 17, 'positive': 6})),
#   ('лишать', defaultdict(int, {'neutral': 1, 'negative': 33, 'positive': 0})),
#   ('атака', defaultdict(int, {'negative': 14, 'positive': 4})),
#   ('мера', defaultdict(int, {'positive': 12, 'negative': 13, 'neutral': 2})),
#   ('использовать',
#    defaultdict(int, {'positive': 12, 'negative': 15, 'neutral': 1})),
#   ('признак', defaultdict(int, {'negative': 13, 'positive': 1, 'neutral': 1})),
#   ('повлечь', defaultdict(int, {'negative': 40, 'positive': 0})),
#   ('признаться', defaultdict(int, {'negative': 11, 'positive': 5})),
#   ('нападение',
#    defaultdict(int,
#                {'negative': 12,
#                 'neutral': 1,
#                 'positive': 2,
#                 'positive/negative': 1})),
#   ('представлять',
#    defaultdict(int, {'negative': 16, 'positive': 2, 'neutral': 2}))],
#  '\n----\n',
#  [('являться',
#    defaultdict(int,
#                {'neutral': 8,
#                 'positive': 18,
#                 'negative': 24,
#                 'positive/negative': 2})),
#   ('Совет', defaultdict(int, {'positive': 11, 'negative': 0})),
#   ('выразить',
#    defaultdict(int, {'positive': 13, 'negative': 29, 'neutral': 1})),
#   (None,
#    defaultdict(int,
#                {'positive': 689,
#                 'negative': 757,
#                 'neutral': 117,
#                 'positive/negative': 86})),
#   ('результат',
#    defaultdict(int,
#                {'negative': 29,
#                 'neutral': 9,
#                 'positive': 21,
#                 'positive/negative': 3})),
#   ('получить',
#    defaultdict(int,
#                {'negative': 60,
#                 'positive': 31,
#                 'neutral': 6,
#                 'positive/negative': 4})),
#   ('один', defaultdict(int, {'neutral': 6, 'negative': 24, 'positive': 27})),
#   ('принять',
#    defaultdict(int, {'positive': 84, 'negative': 8, 'neutral': 36})),
#   ('обратить',
#    defaultdict(int, {'positive': 83, 'neutral': 4, 'negative': 3})),
#   ('стать',
#    defaultdict(int,
#                {'negative': 89,
#                 'positive': 55,
#                 'neutral': 34,
#                 'positive/negative': 7})),
#   ('признать',
#    defaultdict(int, {'negative': 69, 'positive': 16, 'neutral': 3})),
#   ('дом',
#    defaultdict(int, {'positive': 20, 'negative': 4, 'positive/negative': 1})),
#   ('сообщить',
#    defaultdict(int,
#                {'пострадать': 1,
#                 'negative': 23,
#                 'positive': 16,
#                 'neutral': 5,
#                 'positive/negative': 3})),
#   ('должен',
#    defaultdict(int,
#                {'positive': 28,
#                 'neutral': 5,
#                 'negative': 14,
#                 'positive/negative': 2})),
#   ('мочь',
#    defaultdict(int,
#                {'negative': 81,
#                 'positive': 55,
#                 'positive/negative': 8,
#                 'neutral': 19})),
#   ('брать',
#    defaultdict(int, {'negative': 5, 'positive': 30, 'positive/negative': 2})),
#   ('заявить',
#    defaultdict(int,
#                {'negative': 35,
#                 'positive': 28,
#                 'neutral': 10,
#                 'positive/negative': 1})),
#   ('оказаться',
#    defaultdict(int,
#                {'neutral': 7,
#                 'negative': 25,
#                 'positive': 28,
#                 'positive/negative': 3})),
#   ('считать',
#    defaultdict(int,
#                {'negative': 39,
#                 'positive': 16,
#                 'neutral': 3,
#                 'positive/negative': 4})),
#   ('видео',
#    defaultdict(int,
#                {'positive': 13,
#                 'negative': 23,
#                 'positive/negative': 2,
#                 'neutral': 1})),
#   ('назвать',
#    defaultdict(int,
#                {'positive': 30,
#                 'negative': 40,
#                 'positive/negative': 5,
#                 'neutral': 8})),
#   ('часть',
#    defaultdict(int,
#                {'negative': 5,
#                 'positive/negative': 2,
#                 'positive': 14,
#                 'neutral': 4})),
#   ('директор',
#    defaultdict(int, {'positive': 11, 'neutral': 1, 'negative': 0})),
#   ('условие',
#    defaultdict(int, {'neutral': 12, 'positive': 12, 'negative': 5})),
#   ('ролик', defaultdict(int, {'positive': 11, 'negative': 11, 'neutral': 3})),
#   ('делать',
#    defaultdict(int,
#                {'negative': 22,
#                 'positive': 21,
#                 'positive/negative': 3,
#                 'neutral': 12})),
#   ('уровень', defaultdict(int, {'neutral': 8, 'negative': 8, 'positive': 11})),
#   ('просить', defaultdict(int, {'negative': 5, 'positive': 21, 'neutral': 2})),
#   ('то',
#    defaultdict(int,
#                {'negative': 36,
#                 'positive': 29,
#                 'positive/negative': 2,
#                 'neutral': 5})),
#   ('рассказать',
#    defaultdict(int,
#                {'negative': 36,
#                 'neutral': 5,
#                 'positive': 17,
#                 'positive/negative': 5})),
#   ('человек',
#    defaultdict(int, {'positive': 28, 'neutral': 5, 'negative': 21})),
#   ('оказать', defaultdict(int, {'negative': 10, 'positive': 16})),
#   ('организация', defaultdict(int, {'negative': 29, 'positive': 18})),
#   ('сказать',
#    defaultdict(int,
#                {'positive': 13,
#                 'negative': 9,
#                 'positive/negative': 2,
#                 'neutral': 2})),
#   ('рост',
#    defaultdict(int,
#                {'positive': 12,
#                 'positive/negative': 6,
#                 'negative': 6,
#                 'neutral': 2})),
#   ('отстранить', defaultdict(int, {'positive': 22, 'negative': 8})),
#   ('друг', defaultdict(int, {'positive': 25, 'negative': 1})),
#   ('служба', defaultdict(int, {'positive': 13, 'negative': 6})),
#   ('решение',
#    defaultdict(int, {'positive': 23, 'neutral': 11, 'negative': 17})),
#   ('быть',
#    defaultdict(int,
#                {'neutral': 8,
#                 'positive': 13,
#                 'negative': 37,
#                 'positive/negative': 7})),
#   ('борьба',
#    defaultdict(int,
#                {'positive/negative': 1,
#                 'negative': 37,
#                 'positive': 11,
#                 'neutral': 4})),
#   ('одержать',
#    defaultdict(int, {'positive': 22, 'positive/negative': 1, 'negative': 0})),
#   ('режим', defaultdict(int, {'positive': 15, 'negative': 2, 'neutral': 4})),
#   ('вернуть', defaultdict(int, {'positive': 20, 'negative': 5, 'neutral': 1})),
#   ('с', defaultdict(int, {'positive': 82, 'negative': 0})),
#   ('работа', defaultdict(int, {'positive': 17, 'negative': 12, 'neutral': 2})),
#   ('нагрузка', defaultdict(int, {'negative': 2, 'positive': 14})),
#   ('новость',
#    defaultdict(int,
#                {'positive': 73,
#                 'negative': 2,
#                 'neutral': 8,
#                 'positive/negative': 3})),
#   ('отметить',
#    defaultdict(int, {'negative': 13, 'neutral': 6, 'positive': 20})),
#   ('спортсмен', defaultdict(int, {'positive': 30, 'negative': 8})),
#   ('принимать',
#    defaultdict(int, {'positive': 41, 'neutral': 4, 'negative': 3})),
#   ('найти', defaultdict(int, {'positive': 15, 'negative': 13, 'neutral': 1})),
#   ('фактор',
#    defaultdict(int,
#                {'positive': 12,
#                 'neutral': 2,
#                 'negative': 6,
#                 'positive/negative': 2})),
#   ('правило', defaultdict(int, {'negative': 2, 'positive': 22, 'neutral': 1})),
#   ('решить', defaultdict(int, {'neutral': 7, 'positive': 13, 'negative': 12})),
#   ('женщина',
#    defaultdict(int, {'positive': 11, 'negative': 11, 'neutral': 1})),
#   ('добавить',
#    defaultdict(int, {'positive': 14, 'negative': 11, 'neutral': 1})),
#   ('война', defaultdict(int, {'positive': 12, 'negative': 5, 'neutral': 2})),
#   ('вопрос',
#    defaultdict(int,
#                {'positive': 14,
#                 'negative': 7,
#                 'neutral': 2,
#                 'positive/negative': 3})),
#   ('сообщать',
#    defaultdict(int,
#                {'negative': 41,
#                 'positive': 11,
#                 'neutral': 6,
#                 'positive/negative': 3})),
#   ('угроза', defaultdict(int, {'positive': 12, 'negative': 8, 'neutral': 2})),
#   ('летчик', defaultdict(int, {'negative': 7, 'neutral': 1, 'positive': 17})),
#   ('отмечать',
#    defaultdict(int,
#                {'neutral': 3,
#                 'positive': 12,
#                 'negative': 11,
#                 'positive/negative': 1})),
#   ('доказательство', defaultdict(int, {'negative': 9, 'positive': 11})),
#   ('отношение',
#    defaultdict(int,
#                {'positive': 16,
#                 'negative': 5,
#                 'positive/negative': 1,
#                 'neutral': 1})),
#   ('при', defaultdict(int, {'positive': 23, 'neutral': 1, 'negative': 0})),
#   ('сила', defaultdict(int, {'positive': 14, 'negative': 8})),
#   ('мера', defaultdict(int, {'positive': 12, 'negative': 13, 'neutral': 2})),
#   ('использовать',
#    defaultdict(int, {'positive': 12, 'negative': 15, 'neutral': 1})),
#   ('привлечь',
#    defaultdict(int, {'positive': 17, 'neutral': 1, 'negative': 1})),
#   ('сбить', defaultdict(int, {'positive': 12, 'negative': 4})),
#   ('жизнь',
#    defaultdict(int, {'positive/negative': 3, 'negative': 1, 'positive': 11})),
#   ('доход', defaultdict(int, {'positive': 11, 'neutral': 1, 'negative': 1})),
#   ('набирать', defaultdict(int, {'positive': 12, 'negative': 2})),
#   ('Валентина', defaultdict(int, {'positive': 19, 'negative': 0}))])
